# %%
# Rebeccah Duvoisin
# Final Project CITES Traffic Data
from __future__ import  division
import os
import sys
import re as re
import time
from urllib import urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import datetime as dt
import json
import mechanize as mc
import cookielib

# Browser
br = mc.Browser()

# Cookie Jar
cj = cookielib.LWPCookieJar()
br.set_cookiejar(cj)

# Browser options
br.set_handle_equiv(True)
br.set_handle_gzip(True)
br.set_handle_redirect(True)
br.set_handle_referer(True)
br.set_handle_robots(False)

# Follows refresh 0 but not hangs on refresh > 0
br.set_handle_refresh(mc._http.HTTPRefreshProcessor(), max_time=1)

# Want debugging messages?
br.set_debug_http(True)
br.set_debug_redirects(True)
br.set_debug_responses(True)

# from mechanize import Browser
base_url = "http://trade.cites.org"
index_ref = "/en/cites_trade/download?filters[time_range_start]=2015&filters[time_range_end]=2015&filters[exporters_ids][]=all_exp&filters[importers_ids][]=all_imp&filters[sources_ids][]=all_sou&filters[purposes_ids][]=all_pur&filters[terms_ids][]=all_ter&filters[selection_taxon]=taxon&filters[taxon_concepts_ids][]=&filters[reset]=&web_disabled="
index_html = urlopen(base_url + index_ref)

# Parsed version of html - that is what a BeautifulSoup object is.
index = BeautifulSoup(index_html, 'lxml')
index.head
cites_page = base_url + index_ref
print cites_page
type(br)
r = br.open(cites_page)
cites_read = r.read()
cites_read
# Out:
# http://trade.cites.org/en/cites_trade/download?filters[time_range_start]=2015&filters[time_range_end]=2015&filters[exporters_ids][]=all_exp&filters[importers_ids][]=all_imp&filters[sources_ids][]=all_sou&filters[purposes_ids][]=all_pur&filters[terms_ids][]=all_ter&filters[selection_taxon]=taxon&filters[taxon_concepts_ids][]=&filters[reset]=&web_disabled=
# send:
#  'GET /en/cites_trade/download?filters[time_range_start]=2015&filters[time_range_end]=2015&filters[exporters_ids][]=all_exp&filters[importers_ids][]=all_imp&filters[sources_ids][]=all_sou&filters[purposes_ids][]=all_pur&filters[terms_ids][]=all_ter&filters[selection_taxon]=taxon&filters[taxon_concepts_ids][]=&filters[reset]=&web_disabled= HTTP/1.1\r\nHost: trade.cites.org\r\nUser-Agent: Python-urllib/2.7\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/html; charset=utf-8
# header: Transfer-Encoding: chunked
# header: Connection: close
# header: Vary: Accept-Encoding
# header: Status: 200 OK
# header: Cache-Control: max-age=0, private, must-revalidate
# header: Date: Sun, 28 Feb 2016 05:18:53 GMT
# header: X-Request-Id: 452bcd3c72d7a7af0b8d8e42d5e113f5
# header: X-UA-Compatible: IE=Edge,chrome=1
# header: ETag: W/"8cd3903ffc7cd0bee5762eb0590344a5"
# header: X-Runtime: 0.006792
# header: X-Rack-Cache: miss
# header: Set-Cookie: ahoy_visitor=370eaf0c-22aa-425f-9fa3-5a7b4a1c6f39; path=/; expires=Wed, 28-Feb-2018 05:18:53 GMT
# header: Set-Cookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; path=/; expires=Sun, 28-Feb-2016 09:18:53 GMT
# header: X-Powered-By: Phusion Passenger
# header: Server: nginx/1.8.0 + Phusion Passenger
# header: Access-Control-Allow-Origin: *
# header: Access-Control-Allow-Methods: GET, POST, PUT, DELETE, OPTIONS
# header: Access-Control-Allow-Headers: X-Requested-With, X-Prototype-Version
# header: Access-Control-Max-Age: 1728000
# header: Content-Encoding: gzip
# '<!doctype html>\n<html>\n\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <meta itemprop="description" content="The CITES Trade Database, managed by the UNEP World Conservation Monitoring Centre (UNEP-WCMC) on behalf of the CITES Secretariat" />\n  <meta name="description" content="The CITES Trade Database, managed by the UNEP World Conservation Monitoring Centre (UNEP-WCMC) on behalf of the CITES Secretariat" />\n  <meta itemprop="name" content="CITES Trade Database">\n  <link href="/assets/cites_trade-2712723d8a3a9a4b5f8eab510c8bcccd.css" media="screen" rel="stylesheet" type="text/css" />\n  <script src="/assets/cites_trade-9a16c3419ed2962f97c3d4ac1158bdff.js" type="text/javascript"></script>\n  <script>\n    var locale = "en";\n  </script>\n  <title>CITES Trade Database</title>\n  <script>\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'create\', \'UA-49231962-1\', \'auto\');\n    ga(\'send\', \'pageview\');\n\n  </script>\n</head>\n\n<body class="markeeta">\n  <div class="container clearfix">\n    <div class="grid_16 cites_header">\n      <div style="text-align: center;position:relative;width:\'100%\'">\n        <a href="http://trade.cites.org/" target="_blank">\n          <img width=\'100%\' src="/assets/cites_trade/cites_banner_en.jpg" alt="CITES" >\n        </a>\n      </div>\n    </div>\n  \n    <div id="language_links" class="linkStyle">\n        <a href="/es/cites_trade/download">Espanol</a>\n        <a href="/fr/cites_trade/download">Francais</a>\n\n\n    </div>\n\n    <br><br>\n  <div class="grid_16 main_content">\n\n  <table id="net-trade-warning" width="80%" cellspacing="0" cellpadding="10" border="0" align="center" style="display:none">\n  <tbody>\n  <tr>\n    <td valign="top" class="style1">\n      <span style="font-size:14px;font-weight:bold;color:red;">\n        Please read carefully:\n      </span>\n      <br><br>\n      <hr class="space">\n      Net trade is the result of subtracting a country&#x27;s re-exports from its imports. Therefore if your data selection involved imports to or exports from specified countries then you cannot calculate net imports or exports.<br>The result will be gross import or export.\n      <br><br>\n      <hr class="space">\n      <table>\n        <tbody>\n        <tr>\n          <td>\n            <a href="/en/cites_trade/">\n              <button value=" New Search " style="float:right" name="reset" type="submit">\n                <img alt="" src="/assets/cites_trade/page_find.gif">\n                Reselect Data\n              </button>\n            </a>\n          </td>\n          <td>\n            <button id="ignore_warning_button_report" value=" New Search " style="float:right" name="ngTrade" type="submit">\n              <img alt="" src="/assets/cites_trade/page_right.gif">\n              Continue\n            </button>\n          </td>\n        </tr>\n        </tbody>\n      </table>\n    </td>\n  </tr>\n  </tbody>\n</table>\n\n\n  <table id="this_should_not_be_a_table" border="0" align="center">\n    <tr>\n      <td><h3 align="center">REPORTS <br>\n      </h3></td>\n    </tr>\n    <tr>\n      <td style="padding:20px">\n        <span style="font-weight:900;font-size:14px;"> Select output type: </span>\n        <br>\n        <span style="display:none;"\n          id="web-limit-exceeded-error-message">\n          Web output is not available for large subsets.<br>\n          Please download the results in CSV format.\n        </span>\n        <br>\n        <input type="radio" name="outputType" value="web" checked> <span id=\'web-option\'>web</span>\n        <div>\n          <input type="radio" name="outputType" value="csv"> csv\n          <se ...

# %%
print '\nOPENED PAGE\n', cites_read
print br.title()
# Out:
# OPENED PAGE
# <!doctype html>
# <html>
#
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#   <meta itemprop="description" content="The CITES Trade Database, managed by the UNEP World Conservation Monitoring Centre (UNEP-WCMC) on behalf of the CITES Secretariat" />
#   <meta name="description" content="The CITES Trade Database, managed by the UNEP World Conservation Monitoring Centre (UNEP-WCMC) on behalf of the CITES Secretariat" />
#   <meta itemprop="name" content="CITES Trade Database">
#   <link href="/assets/cites_trade-2712723d8a3a9a4b5f8eab510c8bcccd.css" media="screen" rel="stylesheet" type="text/css" />
#   <script src="/assets/cites_trade-9a16c3419ed2962f97c3d4ac1158bdff.js" type="text/javascript"></script>
#   <script>
#     var locale = "en";
#   </script>
#   <title>CITES Trade Database</title>
#   <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-49231962-1', 'auto');
#     ga('send', 'pageview');
#
#   </script>
# </head>
#
# <body class="markeeta">
#   <div class="container clearfix">
#     <div class="grid_16 cites_header">
#       <div style="text-align: center;position:relative;width:'100%'">
#         <a href="http://trade.cites.org/" target="_blank">
#           <img width='100%' src="/assets/cites_trade/cites_banner_en.jpg" alt="CITES" >
#         </a>
#       </div>
#     </div>
#
#     <div id="language_links" class="linkStyle">
#         <a href="/es/cites_trade/download">Espanol</a>
#         <a href="/fr/cites_trade/download">Francais</a>
#
#
#     </div>
#
#     <br><br>
#   <div class="grid_16 main_content">
#
#   <table id="net-trade-warning" width="80%" cellspacing="0" cellpadding="10" border="0" align="center" style="display:none">
#   <tbody>
#   <tr>
#     <td valign="top" class="style1">
#       <span style="font-size:14px;font-weight:bold;color:red;">
#         Please read carefully:
#       </span>
#       <br><br>
#       <hr class="space">
#       Net trade is the result of subtracting a country&#x27;s re-exports from its imports. Therefore if your data selection involved imports to or exports from specified countries then you cannot calculate net imports or exports.<br>The result will be gross import or export.
#       <br><br>
#       <hr class="space">
#       <table>
#         <tbody>
#         <tr>
#           <td>
#             <a href="/en/cites_trade/">
#               <button value=" New Search " style="float:right" name="reset" type="submit">
#                 <img alt="" src="/assets/cites_trade/page_find.gif">
#                 Reselect Data
#               </button>
#             </a>
#           </td>
#           <td>
#             <button id="ignore_warning_button_report" value=" New Search " style="float:right" name="ngTrade" type="submit">
#               <img alt="" src="/assets/cites_trade/page_right.gif">
#               Continue
#             </button>
#           </td>
#         </tr>
#         </tbody>
#       </table>
#     </td>
#   </tr>
#   </tbody>
# </table>
#
#
#   <table id="this_should_not_be_a_table" border="0" align="center">
#     <tr>
#       <td><h3 align="center">REPORTS <br>
#       </h3></td>
#     </tr>
#     <tr>
#       <td style="padding:20px">
#         <span style="font-weight:900;font-size:14px;"> Select output type: </span>
#         <br>
#         <span style="display:none;"
#           id="web-limit-exceeded-error-message">
#           Web output is not available for large subsets.<br>
#           Please download the results in CSV format.
#         </span>
#         <br>
#         <input type="radio" name="outputType" value="web" checked> <span id='web-option'>web</span>
#         <div>
#           <input type="radio" name="outputType" value="csv"> csv
#           <select name="csvSeparator" style='background-color:#CCFFFF' id="csv_separator" >
#             <option value="comma"> comma separated </option>
#             <option value="semicolon"> semicolon separated </option>
#           </select>
#           <img src="/assets/cites_trade/information3.gif" class="qtipify" title="Trouble viewing outputs? Try changing the .csv output type to semicolon separated." />
#         </div>
#       </td>
#     </tr>
#
#     <tr id="net_gross_options">
#       <td style="padding:20px">
#         <span style="font-weight:900;font-size:14px;"> Select report type:  </span>
#         <br>
#         <br>
#         <input name="report" id="report_comparative" type="radio" value="comparative" checked="checked"  /> Comparative Tabulations
#         <br>
#         <div id="gross_net_section">
#           <input name="report" id="report_gross_net" type="radio" value="gross_net" /> Gross/Net Trade Tabulations <select name="reportType" style='background-color:#CCFFFF' id="report_type" >
#           <option value="gross_exports"> Gross Exports </option>
#           <option value="gross_imports"> Gross Imports </option>
#           <option value="net_exports"> Net Exports </option>
#           <option value="net_imports"> Net Imports </option>
#         </div>
#       </select>
#     </td></tr>
#     <tr>
#       <td>
#         <div align="right">
#           <button style="float:left; margin-top:12px" id='button_report' value=" Get report ">
#           <img src="/assets/cites_trade/page.gif" alt=""/>
#           Get report
#           </button>
#           <a id='view_genie' href="" style="display:none"></a>
#           <a id='download_genie' href="#" style="display:none"></a>
#         </div>
#
#         <p><br><br></p>
#
#       </td></tr>
#     </form>
#     <tr><td>
#       <hr>
#
#       <div id="new_search_wrapper" align="center">
#
#         <a id="new_search" style="float:left" href="/en/cites_trade/">
#           <button id="new_search" style="float:left" value=" New Search ">
#             <img src="/assets/cites_trade/refresh1.png" alt=""/> New Search
#           </button>
#         </a>
#
#         <br>
#       </div>
#       <br />
#       <div align="left">
#         <strong>Download: </strong>
#       <a href="/cites_trade_guidelines/en-CITES_Trade_Database_Guide.pdf">A Guide to Using the CITES Trade Database</a>
#
#       </div>
#
#     </td></tr>
#   </table>
#
# </div>
#
#   <div class="container clearfix">
#   <div class="grid_16 footer">
#   <br />
#   <div class='grid_14' align="center">
#   <font size="-2" face="Verdana, Arial, Helvetica, sans-serif">
#   The CITES Trade Database was developed and is maintained by UNEP-WCMC on behalf of the CITES Secretariat.
#   :&nbsp;<br>
#   <a href="http://www.cites.org">CITES</a> |
#   <a href="http://www.unep-wcmc.org">UNEP-WCMC</a> |
#   <a href="http://www.speciesplus.net">Species+</a> |
#   <a href="mailto:species@unep-wcmc.org" target="_blank"> Contact Us </a>
#   </font>
#   </div>
#   <div class='grid_1' align='right' ><a href="/"><img src="/assets/cites_trade/logoUNEP_WCMC_Transparent_sm.gif" alt="UNEP-WCMC" width="80" height="44" border="0" float='right'></a></div>
#   </div>
#
#   <!-- UserVoice JavaScript SDK (only needed once on a page) -->
#   <script>(function(){var uv=document.createElement('script');uv.type='text/javascript';uv.async=true;uv.src='//widget.uservoice.com/uYdwK4zYfiO4lbGJSYu2Vw.js';var s=document.getElementsByTagName('script')[0];s.parentNode.insertBefore(uv,s)})()</script>
#
#   <!-- A tab to launch the Classic Widget -->
#   <script>
#     UserVoice = window.UserVoice || [];
#     UserVoice.push(['showTab', 'classic_widget', {
#       mode: 'feedback',
#       primary_color: '#ffffff',
#       link_color: '#55a336',
#       forum_id: 246762,
#       feedback_tab_name: 'Feedback',
#       tab_label: 'Feedback',
#       tab_color: '#469c56',
#       tab_position: 'middle-right',
#       tab_inverted: true
#     }]);
#   </script>
# </body>
# </html>
#
# CITES Trade Database

# %%
# Find form to manipulate selections, get download report button object.
globe_form = br.global_form()
print '\nGLOBAL FORM\n', globe_form
print '\nSEE ALL CONTROLS:\n'
download_button = None
control_number = 0
for c in globe_form.controls:
    print '\n\t', control_number,'CONTROL:', 'Name =', c.name, ', Value:', c.value, \
          ', Type:', c.type, ', Read only?:', c.readonly, ', ID:', c.id
    try:
        print '\t\t',  c.attrs
    except:
        print ""
    if c.id == 'button_report':
        download_button = c
    control_number += 1
# Out:
# GLOBAL FORM
# <GET http://trade.cites.org/en/cites_trade/download?filters[time_range_start]=2015&filters[time_range_end]=2015&filters[exporters_ids][]=all_exp&filters[importers_ids][]=all_imp&filters[sources_ids][]=all_sou&filters[purposes_ids][]=all_pur&filters[terms_ids][]=all_ter&filters[selection_taxon]=taxon&filters[taxon_concepts_ids][]=&filters[reset]=&web_disabled= application/x-www-form-urlencoded
#   <SubmitButtonControl(reset= New Search ) (readonly)>
#   <SubmitButtonControl(ngTrade= New Search ) (readonly)>
#   <RadioControl(outputType=[*web, csv])>
#   <SelectControl(csvSeparator=[*comma, semicolon])>
#   <RadioControl(report=[*comparative, gross_net])>
#   <SelectControl(reportType=[*gross_exports, gross_imports, net_exports, net_imports])>
#   <SubmitButtonControl(<None>= Get report ) (readonly)>
#   <SubmitButtonControl(<None>= New Search ) (readonly)>>
#
# SEE ALL CONTROLS:
#
#
# 	0 CONTROL: Name = reset , Value:  New Search  , Type: submitbutton , Read only?: True , ID: None
# 		{'style': 'float:right', 'type': 'submit', 'name': 'reset', 'value': ' New Search '}
#
# 	1 CONTROL: Name = ngTrade , Value:  New Search  , Type: submitbutton , Read only?: True , ID: ignore_warning_button_report
# 		{'style': 'float:right', 'type': 'submit', 'id': 'ignore_warning_button_report', 'value': ' New Search ', 'name': 'ngTrade'}
#
# 	2 CONTROL: Name = outputType , Value: ['web'] , Type: radio , Read only?: False , ID: None
#
#
# 	3 CONTROL: Name = csvSeparator , Value: ['comma'] , Type: select , Read only?: False , ID: csv_separator
# 		{'style': 'background-color:#CCFFFF', 'name': 'csvSeparator', 'id': 'csv_separator'}
#
# 	4 CONTROL: Name = report , Value: ['comparative'] , Type: radio , Read only?: False , ID: report_comparative
#
#
# 	5 CONTROL: Name = reportType , Value: ['gross_exports'] , Type: select , Read only?: False , ID: report_type
# 		{'style': 'background-color:#CCFFFF', 'name': 'reportType', 'id': 'report_type'}
#
# 	6 CONTROL: Name = None , Value:  Get report  , Type: submitbutton , Read only?: True , ID: button_report
# 		{'style': 'float:left; margin-top:12px', 'type': 'submit', 'id': 'button_report', 'value': ' Get report '}
#
# 	7 CONTROL: Name = None , Value:  New Search  , Type: submitbutton , Read only?: True , ID: new_search
# 		{'style': 'float:left', 'type': 'submit', 'id': 'new_search', 'value': ' New Search '}

# %%
# Find 'Select Output Type' and 'Select Report Type' Controls
output_control = None
report_control = None
writable_controls = [c for c in globe_form.controls if not c.readonly]
print '\nWRITEABLE CONTROLS'
control_number = 0
for c in writable_controls:
    print '\t', control_number,'CONTROL:', 'Name =', c.name, ', Value:', c.value, ', Type:', c.type, ', Read only?:', c.readonly
    control_number += 1
    if c.name == 'outputType':
        output_control = c
    elif c.name == 'report':
        report_control = c
# Out:
# WRITEABLE CONTROLS
# 	0 CONTROL: Name = outputType , Value: ['web'] , Type: radio , Read only?: False
# 	1 CONTROL: Name = csvSeparator , Value: ['comma'] , Type: select , Read only?: False
# 	2 CONTROL: Name = report , Value: ['comparative'] , Type: radio , Read only?: False
# 	3 CONTROL: Name = reportType , Value: ['gross_exports'] , Type: select , Read only?: False

# %%
print '\nALL CONTROLS:', '\n\tDOWNLOAD BUTTON (Get Report):', download_button, '\n\t\tAttrs:', download_button.attrs, \
      '\n\n\tOUTPUT CONTROL:', output_control, '\n\t\tItems:', output_control.items, \
      '\n\n\tREPORT CONTROL:', report_control, '\n\t\tItems:', report_control.items
# Out:
# ALL CONTROLS:
# 	DOWNLOAD BUTTON (Get Report): <SubmitButtonControl(<None>= Get report ) (readonly)>
# 		Attrs: {'style': 'float:left; margin-top:12px', 'type': 'submit', 'id': 'button_report', 'value': ' Get report '}
#
# 	OUTPUT CONTROL: <RadioControl(outputType=[*web, csv])>
# 		Items: [<Item name='web' id=None type='radio' checked='checked' name='outputType' value='web'>, <Item name='csv' id=None type='radio' name='outputType' value='csv'>]
#
# 	REPORT CONTROL: <RadioControl(report=[*comparative, gross_net])>
# 		Items: [<Item name='comparative' id='report_comparative' type='radio' checked='checked' name='report' value='comparative' id='report_comparative'>, <Item name='gross_net' id='report_gross_net' type='radio' name='report' value='gross_net' id='report_gross_net'>]

# %%
# View radio outputType control items
csv_option = output_control.get('csv')
web_option = output_control.get('web')
comparative_option = report_control.get('comparative')
for option in [csv_option, web_option, comparative_option]:
    print '\nOPTION:', 'Name:', option.name, ', ID:', option.id, ', ATTRIBUTES', option.attrs, ', Selected?', option.selected
print '\nOUTPUT_CONTROL ITEMS', output_control.items
print '\nREPORT_CONTROL ITEMS', report_control.items
# Out:
# OPTION: Name: csv , ID: None , ATTRIBUTES {'type': 'radio', 'name': 'outputType', 'value': 'csv'} , Selected? False
#
# OPTION: Name: web , ID: None , ATTRIBUTES {'type': 'radio', 'checked': 'checked', 'name': 'outputType', 'value': 'web'} , Selected? True
#
# OPTION: Name: comparative , ID: report_comparative , ATTRIBUTES {'type': 'radio', 'checked': 'checked', 'name': 'report', 'value': 'comparative', 'id': 'report_comparative'} , Selected? True
#
# OUTPUT_CONTROL ITEMS [<Item name='web' id=None type='radio' checked='checked' name='outputType' value='web'>, <Item name='csv' id=None type='radio' name='outputType' value='csv'>]
#
# REPORT_CONTROL ITEMS [<Item name='comparative' id='report_comparative' type='radio' checked='checked' name='report' value='comparative' id='report_comparative'>, <Item name='gross_net' id='report_gross_net' type='radio' name='report' value='gross_net' id='report_gross_net'>]

# %%
#  Set output control item to csv instead of web
output_control.get('web').selected = False
output_control.get('csv').selected = True
for option in [csv_option, web_option, comparative_option]:
    print '\nOPTION:', 'Name:', option.name, ', ID:', option.id, ', ATTRIBUTES', option.attrs, ', Selected?', option.selected
print '\nOUTPUT_CONTROL ITEMS', output_control.items
print '\nREPORT_CONTROL ITEMS', report_control.items
# Out:
# OPTION: Name: csv , ID: None , ATTRIBUTES {'type': 'radio', 'name': 'outputType', 'value': 'csv'} , Selected? True
#
# OPTION: Name: web , ID: None , ATTRIBUTES {'type': 'radio', 'checked': 'checked', 'name': 'outputType', 'value': 'web'} , Selected? False
#
# OPTION: Name: comparative , ID: report_comparative , ATTRIBUTES {'type': 'radio', 'checked': 'checked', 'name': 'report', 'value': 'comparative', 'id': 'report_comparative'} , Selected? True
#
# OUTPUT_CONTROL ITEMS [<Item name='web' id=None type='radio' checked='checked' name='outputType' value='web'>, <Item name='csv' id=None type='radio' name='outputType' value='csv'>]
#
# REPORT_CONTROL ITEMS [<Item name='comparative' id='report_comparative' type='radio' checked='checked' name='report' value='comparative' id='report_comparative'>, <Item name='gross_net' id='report_gross_net' type='radio' name='report' value='gross_net' id='report_gross_net'>]

# %%
#  Create a second request object with the prefered output type
rq_with_csv = globe_form.click()
try:
    csv_response = mc.urlopen(rq_with_csv)
except mc.HTTPError, csv_response:
    pass
# csv_response = br.submit()
print '\nRESPONSE TO CSV REQUEST:\n', csv_response.geturl()
for name, value in csv_response.info().items():
    print '-{}:\t{}'.format(name.title(), value)
    
# new_link = csv_response.geturl()
# response = br.follow_link(new_link)
# print response.geturl()
# Out:
# RESPONSE TO CSV REQUEST:
# http://trade.cites.org/en/cites_trade/download?reset=+New+Search+&outputType=csv&csvSeparator=comma&report=comparative&reportType=gross_exports
# -Status:	200 OK
# -X-Request-Id:	2d442d284d6fe4b660f1acdb4397b8eb
# -Access-Control-Allow-Headers:	X-Requested-With, X-Prototype-Version
# -X-Powered-By:	Phusion Passenger
# -Transfer-Encoding:	chunked
# -Set-Cookie:	ahoy_visit=094b3746-114f-4ffe-9ea5-bb917430924f; path=/; expires=Sun, 28-Feb-2016 09:18:54 GMT
# -Access-Control-Max-Age:	1728000
# -Vary:	Accept-Encoding
# -X-Runtime:	0.007733
# -Server:	nginx/1.8.0 + Phusion Passenger
# -Connection:	close
# -Etag:	"8cd3903ffc7cd0bee5762eb0590344a5"
# -X-Ua-Compatible:	IE=Edge,chrome=1
# -Cache-Control:	must-revalidate, private, max-age=0
# -Date:	Sun, 28 Feb 2016 05:18:54 GMT
# -Access-Control-Allow-Origin:	*
# -Access-Control-Allow-Methods:	GET, POST, PUT, DELETE, OPTIONS
# -Content-Type:	text/html; charset=utf-8
# -X-Rack-Cache:	miss

# %%
# Now click the 'Get Report' to download the csv file (get button's url)
print download_button.attrs
print download_button.disabled
print download_button.type
button_type = download_button.type
button_id = download_button.id
print 'BUTTON TYPE', button_type, ', BUTTON ID:', button_id
response = globe_form.click(type=button_type, nr=0)
print response
# Out:
# {'style': 'float:left; margin-top:12px', 'type': 'submit', 'id': 'button_report', 'value': ' Get report '}
# False
# submitbutton
# BUTTON TYPE submitbutton , BUTTON ID: button_report
# <Request for http://trade.cites.org/en/cites_trade/download?reset=+New+Search+&outputType=csv&csvSeparator=comma&report=comparative&reportType=gross_exports>

# %%
# print '\nREAD RESPONSE TO CSV REQUEST:\n', csv_response.read()

# %%
# globe_form = br.global_form()

# %%
# Get img src of the button of corresponding id and type
all_inputs = index.find_all('button')
print '\nBUTTONS:', len(all_inputs), button_id
button_number = 0
download_button_src = None
for button in all_inputs:
    print '\nBUTTON', button_number,':',  button.attrs, button.id
    image = button.find('img')
    image_src = image.get('src')
    if 'id' in button.attrs:
        print button.attrs['id'] == button_id
        if button.attrs['id'] == button_id:
            download_button_src = image_src
            break
    print 'SRC', download_button_src
    try:
        print '\tIMAGE', image
        print '\tIMAGE SOURCE:', image_src
    except:
        pass
    button_number += 1
print '\nIMAGE SRC FILE CHOSEN:', download_button_src
# print base_url, index_ref,
# Out:
# BUTTONS: 4 button_report
#
# BUTTON 0 : {'style': 'float:right', 'type': 'submit', 'name': 'reset', 'value': ' New Search '} None
# SRC None
# 	IMAGE <img alt="" src="/assets/cites_trade/page_find.gif"/>
# 	IMAGE SOURCE: /assets/cites_trade/page_find.gif
#
# BUTTON 1 : {'style': 'float:right', 'type': 'submit', 'id': 'ignore_warning_button_report', 'value': ' New Search ', 'name': 'ngTrade'} None
# False
# SRC None
# 	IMAGE <img alt="" src="/assets/cites_trade/page_right.gif"/>
# 	IMAGE SOURCE: /assets/cites_trade/page_right.gif
#
# BUTTON 2 : {'style': 'float:left; margin-top:12px', 'id': 'button_report', 'value': ' Get report '} None
# True
#
# IMAGE SRC FILE CHOSEN: /assets/cites_trade/page.gif

# %%
cwd = os.getcwd()
cwd
# Out:
# '/home/studentuser/ppha_30530/final'

# %%
# Now try clicking with found url
download_full_src = base_url + download_button_src
print download_full_src
# Retrieve file
all_links = {}
all_pds = all_links.copy()
gross_exports = "/cites_trade/exports/download?filters[time_range_start]=2015&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=all_sou&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_exports&amp;filters[csv_separator]=comma"  
gross_imports = "/cites_trade/exports/download?filters[time_range_start]=2015&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=all_sou&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_imports&amp;filters[csv_separator]=comma"  
confcomp = "/cites_trade/exports/download?filters[time_range_start]=2010&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=109&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=comptab&amp;filters[csv_separator]=comma" 
conf_gexport = "/cites_trade/exports/download?filters[time_range_start]=2010&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=109&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_exports&amp;filters[csv_separator]=comma" 
conf_gimport = "/cites_trade/exports/download?filters[time_range_start]=2010&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=109&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_imports&amp;filters[csv_separator]=comma"
all_links['gross_exports'] = gross_exports
all_links['gross_imports'] = gross_imports
all_links['confcomp'] = confcomp
all_links['conf_gexport'] = conf_gexport
all_links['conf_gimport'] = conf_gimport
for copied_link in all_links.keys():
    download_full_src = base_url + all_links[copied_link]
    f = br.retrieve(download_full_src)[0]
    fhandler = pd.read_csv(f)
    fhandler.to_csv(cwd+"/"+copied_link)
    fhandler.columns
    all_pds[copied_link] = fhandler
gexports = all_pds['gross_exports']
gimports = all_pds['gross_imports']
confcomp = all_pds['confcomp']
conf_gexport = all_pds['conf_gexport']
conf_gimport = all_pds['conf_gimport']
# fhandler
# with open('/home/studentuser/ppha_30530/final/exporeted_csv.csv', 'w') as f:
#     f.write(fhandler.read())
# Out:
# http://trade.cites.org/assets/cites_trade/page.gif
# send:
#  'GET /cites_trade/exports/download?filters[time_range_start]=2015&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=all_sou&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_exports&amp;filters[csv_separator]=comma HTTP/1.1\r\nHost: trade.cites.org\r\nUser-Agent: Python-urllib/2.7\r\nCookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; ahoy_visitor=370eaf0c-22aa-425f-9fa3-5a7b4a1c6f39\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/csv
# header: Content-Length: 805
# header: Connection: close
# header: Status: 200 OK
# header: Cache-Control: private
# header: Date: Sun, 28 Feb 2016 05:34:02 GMT
# header: X-Request-Id: a4892dd5710011dcc3f31b4cb050d6d3
# header: Content-Disposition: attachment; filename="gross_exports_2016-02-28 04:35_comma_separated.csv"
# header: Content-Transfer-Encoding: binary
# header: X-UA-Compatible: IE=Edge,chrome=1
# header: X-Runtime: 0.023603
# header: X-Rack-Cache: miss
# header: Set-Cookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; path=/; expires=Sun, 28-Feb-2016 09:34:02 GMT
# header: X-Powered-By: Phusion Passenger
# header: Server: nginx/1.8.0 + Phusion Passenger
# header: Access-Control-Allow-Origin: *
# header: Access-Control-Allow-Methods: GET, POST, PUT, DELETE, OPTIONS
# header: Access-Control-Allow-Headers: X-Requested-With, X-Prototype-Version
# header: Access-Control-Max-Age: 1728000
# send:
#  'GET /cites_trade/exports/download?filters[time_range_start]=2010&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=109&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_exports&amp;filters[csv_separator]=comma HTTP/1.1\r\nHost: trade.cites.org\r\nUser-Agent: Python-urllib/2.7\r\nCookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; ahoy_visitor=370eaf0c-22aa-425f-9fa3-5a7b4a1c6f39\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/csv
# header: Content-Length: 368519
# header: Connection: close
# header: Status: 200 OK
# header: Cache-Control: private
# header: Date: Sun, 28 Feb 2016 05:34:05 GMT
# header: X-Request-Id: 312ab4a1cc25ae6209deebb0e968eb40
# header: Content-Disposition: attachment; filename="gross_exports_2016-02-28 05:04_comma_separated.csv"
# header: Content-Transfer-Encoding: binary
# header: X-UA-Compatible: IE=Edge,chrome=1
# header: X-Runtime: 2.273301
# header: X-Rack-Cache: miss
# header: Set-Cookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; path=/; expires=Sun, 28-Feb-2016 09:34:03 GMT
# header: X-Powered-By: Phusion Passenger
# header: Server: nginx/1.8.0 + Phusion Passenger
# header: Access-Control-Allow-Origin: *
# header: Access-Control-Allow-Methods: GET, POST, PUT, DELETE, OPTIONS
# header: Access-Control-Allow-Headers: X-Requested-With, X-Prototype-Version
# header: Access-Control-Max-Age: 1728000
# send:
#  'GET /cites_trade/exports/download?filters[time_range_start]=2010&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=109&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_imports&amp;filters[csv_separator]=comma HTTP/1.1\r\nHost: trade.cites.org\r\nUser-Agent: Python-urllib/2.7\r\nCookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; ahoy_visitor=370eaf0c-22aa-425f-9fa3-5a7b4a1c6f39\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/csv
# header: Content-Length: 222181
# header: Connection: close
# header: Status: 200 OK
# header: Cache-Control: private
# header: Date: Sun, 28 Feb 2016 05:34:08 GMT
# header: X-Request-Id: fdd826ae67929e5134415613734ad67e
# header: Content-Disposition: attachment; filename="gross_imports_2016-02-28 05:11_comma_separated.csv"
# header: Content-Transfer-Encoding: binary
# header: X-UA-Compatible: IE=Edge,chrome=1
# header: X-Runtime: 2.039537
# header: X-Rack-Cache: miss
# header: Set-Cookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; path=/; expires=Sun, 28-Feb-2016 09:34:06 GMT
# header: X-Powered-By: Phusion Passenger
# header: Server: nginx/1.8.0 + Phusion Passenger
# header: Access-Control-Allow-Origin: *
# header: Access-Control-Allow-Methods: GET, POST, PUT, DELETE, OPTIONS
# header: Access-Control-Allow-Headers: X-Requested-With, X-Prototype-Version
# header: Access-Control-Max-Age: 1728000
# send:
#  'GET /cites_trade/exports/download?filters[time_range_start]=2015&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=all_sou&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=gross_imports&amp;filters[csv_separator]=comma HTTP/1.1\r\nHost: trade.cites.org\r\nUser-Agent: Python-urllib/2.7\r\nCookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; ahoy_visitor=370eaf0c-22aa-425f-9fa3-5a7b4a1c6f39\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/csv
# header: Content-Length: 1809
# header: Connection: close
# header: Status: 200 OK
# header: Cache-Control: private
# header: Date: Sun, 28 Feb 2016 05:34:09 GMT
# header: X-Request-Id: 55cbd1e45f0c10c63f0f4448a548593c
# header: Content-Disposition: attachment; filename="gross_imports_2016-02-28 04:46_comma_separated.csv"
# header: Content-Transfer-Encoding: binary
# header: X-UA-Compatible: IE=Edge,chrome=1
# header: X-Runtime: 0.027376
# header: X-Rack-Cache: miss
# header: Set-Cookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; path=/; expires=Sun, 28-Feb-2016 09:34:09 GMT
# header: X-Powered-By: Phusion Passenger
# header: Server: nginx/1.8.0 + Phusion Passenger
# header: Access-Control-Allow-Origin: *
# header: Access-Control-Allow-Methods: GET, POST, PUT, DELETE, OPTIONS
# header: Access-Control-Allow-Headers: X-Requested-With, X-Prototype-Version
# header: Access-Control-Max-Age: 1728000
# send:
#  'GET /cites_trade/exports/download?filters[time_range_start]=2010&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=109&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=comptab&amp;filters[csv_separator]=comma HTTP/1.1\r\nHost: trade.cites.org\r\nUser-Agent: Python-urllib/2.7\r\nCookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; ahoy_visitor=370eaf0c-22aa-425f-9fa3-5a7b4a1c6f39\r\nConnection: close\r\nAccept-Encoding: gzip\r\n\r\n'
# reply:
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/csv
# header: Content-Length: 1321350
# header: Connection: close
# header: Status: 200 OK
# header: Cache-Control: private
# header: Date: Sun, 28 Feb 2016 05:34:11 GMT
# header: X-Request-Id: a52d83cde9bc9736c57e0ba61fe4b698
# header: Content-Disposition: attachment; filename="comptab_2016-02-28 05:07_comma_separated.csv"
# header: Content-Transfer-Encoding: binary
# header: X-UA-Compatible: IE=Edge,chrome=1
# header: X-Runtime: 2.074182
# header: X-Rack-Cache: miss
# header: Set-Cookie: ahoy_visit=02acafd0-f423-4c7a-81a7-5832d2b2a8d8; path=/; expires=Sun, 28-Feb-2016 09:34:09 GMT
# header: X-Powered-By: Phusion Passenger
# header: Server: nginx/1.8.0 + Phusion Passenger
# header: Access-Control-Allow-Origin: *
# header: Access-Control-Allow-Methods: GET, POST, PUT, DELETE, OPTIONS
# header: Access-Control-Allow-Headers: X-Requested-With, X-Prototype-Version
# header: Access-Control-Max-Age: 1728000

# %%
# Top Gross Exporters 
gexports.columns
top_gross_exporters = gexports.groupby('Country').size().sort_values(ascending=False)
top_gross = pd.DataFrame()
top_gross['Total Gross Exports 2015'] = top_gross_exporters
print top_gross.columns
print top_gross[:5]
top_gross.columns
top_gross['Country'] = top_gross.index.tolist()
top_gross.index = range(0, len(top_gross))
top_gross
# Out:
# Index([u'Total Gross Exports 2015'], dtype='object')
#          Total Gross Exports 2015
# Country
# MN                             15
# ZA                              1
# SL                              1
# NL                              1
# LY                              1
#    Total Gross Exports 2015 Country
# 0                        15      MN
# 1                         1      ZA
# 2                         1      SL
# 3                         1      NL
# 4                         1      LY
# 5                         1      CZ
# 6                         1      CI

# %%
print gimports.columns
top_gross_importers = gimports.groupby('Country').size().sort_values(ascending=False)
# top_gross['Total Gross Imports 2015'] = top_gross_importers
totgi = 'Total Gross Imports 2015'
totge = 'Total Gross Exports 2015'
print top_gross.columns
top_gross_importers = pd.DataFrame(top_gross_importers)
# top_gross_importerss['Country'] = top_gross_importers.index
# top_gross_importerss[totgi] = top_gross_importers
# top_gross_importerss = top_gross_importers.to_frame()
print top_gross_importerss.columns
top_gross_importers['Country'] = top_gross_importers.index.tolist()
top_gross_importers[totgi] = top_gross_importers[top_gross_importers.columns[0]]
print top_gross_importers.columns
top_gross_importers.index = range(0, len(top_gross_importers))
print top_gross_importers.columns
top_gross_importers = top_gross_importers.drop([top_gross_importers.columns[0]], axis=1)
top_gross_importers
top_gross = top_gross.merge(top_gross_importers, on='Country', how='outer')

top_gross
# top_gross[totge] = top_gross[top_gross.columns[0]]
# print 
# top_gross_importers
# top_gross
# top_gross_importers.index
# top_gross = top_gross.merge(top_gross_importers, on='Country', how='outer')
# top_gross_importers.index
# Out:
# Index([u'App.', u'Taxon', u'Term', u'Unit', u'Country', u'2015'], dtype='object')
# Index([u'Total Gross Exports 2015', u'Country'], dtype='object')
# Int64Index([0], dtype='int64')
# Index([0, u'Country', u'Total Gross Imports 2015'], dtype='object')
# Index([0, u'Country', u'Total Gross Imports 2015'], dtype='object')
#     Total Gross Exports 2015 Country  Total Gross Imports 2015
# 0                         15      MN                         1
# 1                          1      ZA                         1
# 2                          1      SL                       NaN
# 3                          1      NL                         1
# 4                          1      LY                         1
# 5                          1      CZ                         1
# 6                          1      CI                         1
# 7                        NaN      CN                         6
# 8                        NaN      US                         6
# 9                        NaN      AT                         3
# 10                       NaN      RU                         3
# 11                       NaN      MX                         3
# 12                       NaN      LT                         2
# 13                       NaN      FR                         2
# 14                       NaN      GB                         2
# 15                       NaN      JP                         2
# 16                       NaN      IT                         2
# 17                       NaN      TR                         2
# 18                       NaN      BB                         1
# 19                       NaN      CA                         1
# 20                       NaN      CH                         1
# 21                       NaN      DE                         1
# 22                       NaN      DO                         1
# 23                       NaN      ES                         1
# 24                       NaN      SE                         1
# 25                       NaN      NZ                         1
# 26                       NaN      HU                         1
# 27                       NaN      JM                         1
# 28                       NaN      JO                         1

# %%
print confcomp.columns
byexporter = confcomp.groupby('Exporter')
byimporter = confcomp.groupby('Importer')
top_importers = byimporter.size().sort_values(ascending=False)
top_importer = pd.DataFrame()
top_importer['Total Imports (2010-)'] = top_importers
print top_importer.columns
print top_importer[:5]
top_exporter = pd.DataFrame()
top_exporters = byexporter.size().sort_values(ascending=False)
top_exporter['Total Exports (2010-)'] = top_exporters
print top_exporter.columns
print top_exporter[:5]
# Out:
# Index([u'Year', u'App.', u'Taxon', u'Class', u'Order', u'Family', u'Genus',
#        u'Importer', u'Exporter', u'Origin', u'Importer reported quantity',
#        u'Exporter reported quantity', u'Term', u'Unit', u'Purpose', u'Source'],
#       dtype='object')
# Index([u'Total Imports (2010-)'], dtype='object')
#           Total Imports (2010-)
# Importer
# US                        11735
# NZ                          571
# NO                          160
# CA                          131
# XX                           99
# Index([u'Total Exports (2010-)'], dtype='object')
#           Total Exports (2010-)
# Exporter
# US                         1098
# MX                          951
# ID                          942
# CN                          859
# CA                          767

# %%
conf_gexport
# Out:
#      App.                      Taxon                      Term Unit Country  \
# 0       I           Acinonyx jubatus               derivatives  NaN      CN
# 1       I           Acinonyx jubatus                      live  NaN      AE
# 2       I           Acinonyx jubatus                      live  NaN      SO
# 3       I           Acinonyx jubatus                      live  NaN      XX
# 4       I           Acinonyx jubatus               skin pieces  NaN      GB
# 5       I           Acinonyx jubatus               skin pieces  NaN      NG
# 6       I           Acinonyx jubatus                     skins  NaN      AE
# 7       I           Acinonyx jubatus                     skins  NaN      GB
# 8       I           Acinonyx jubatus                     skins  NaN      US
# 9       I           Acinonyx jubatus                     skins  NaN      ZA
# 10      I           Acipenser sturio                  medicine  NaN      SG
# 11      I        Addax nasomaculatus                    skulls  NaN      GB
# 12      I        Addax nasomaculatus                  trophies  NaN      US
# 13      I          Aegypius monachus                      live  NaN      PT
# 14      I           Agave parviflora                     seeds  NaN      DE
# 15      I            Ailurus fulgens                      live  NaN      CA
# 16      I         Alligator sinensis                      feet  NaN      CN
# 17      I         Alligator sinensis  leather products (large)  NaN      JP
# 18      I             Alligator spp.                     heads  NaN      RU
# 19      I             Alligator spp.  leather products (small)  NaN      US
# 20      I                Aloe hybrid                      live  NaN      JP
# 21      I                 Aloe laeta                      live  NaN      DE
# 22      I              Aloe suzannae                      live  NaN      DE
# 23      I          Alouatta palliata                    skulls  NaN      CA
# 24      I             Alouatta pigra             bone carvings  NaN      GT
# 25      I       Amazona auropalliata                      live  NaN      BS
# 26      I       Amazona auropalliata                      live  NaN      MX
# 27      I       Amazona auropalliata                      live  NaN      PH
# 28      I       Amazona auropalliata                      live  NaN      XX
# 29      I        Amazona barbadensis                      live  NaN      CA
# ...   ...                        ...                       ...  ...     ...
# 8545  III          Sarcoramphus papa                  feathers    g      SV
# 8546  III          Sarcoramphus papa                  feathers  NaN      CO
# 8547  III       Sphiggurus mexicanus                      hair  NaN      MX
# 8548  III       Sphiggurus mexicanus                      live  NaN      XX
# 8549  III          Tamandua mexicana                      live  NaN      XX
# 8550  III            Viverra zibetha                      hair  NaN      JP
# 8551  III            Viverra zibetha             hair products  NaN      JP
# 8552  III         Vulpes bengalensis                 specimens  NaN      BD
# 8553  III      Xenochrophis piscator                    bodies  NaN      AE
# 8554  III      Xenochrophis piscator                    bodies  NaN      CN
# 8555  III      Xenochrophis piscator                    bodies  NaN      KH
# 8556  III      Xenochrophis piscator                    bodies  NaN      LA
# 8557  III      Xenochrophis piscator                    bodies  NaN      RU
# 8558  III      Xenochrophis piscator                    bodies  NaN      TH
# 8559  III      Xenochrophis piscator                    bodies  NaN      TW
# 8560  III      Xenochrophis piscator                    bodies  NaN      US
# 8561  III      Xenochrophis piscator                    bodies  NaN      VN
# 8562  III      Xenochrophis piscator                    bodies  NaN      XX
# 8563  III      Xenochrophis piscator               derivatives  NaN      KH
# 8564  III      Xenochrophis piscator               derivatives  NaN      LA
# 8565  III      Xenochrophis piscator               derivatives  NaN      TH
# 8566  III      Xenochrophis piscator               derivatives  NaN      VN
# 8567  III      Xenochrophis piscator  leather products (large)  NaN      HK
# 8568  III      Xenochrophis piscator                      live  NaN      HK
# 8569  III      Xenochrophis piscator                      live  NaN      ID
# 8570  III      Xenochrophis piscator                  medicine  NaN      TH
# 8571  III      Xenochrophis piscator               skin pieces  NaN      HK
# 8572    N              Bubulcus ibis                  feathers  NaN      ID
# 8573    N        Pterapogon kauderni                      live  NaN      ID
# 8574    N  Trachemys scripta elegans                      live  NaN      XX
#
#       2010  2011  2012  2013  2014  2015
# 0        2   NaN   NaN   NaN   NaN   NaN
# 1      NaN     5   NaN   NaN   NaN   NaN
# 2       15   NaN   NaN   NaN   NaN   NaN
# 3        5   NaN   NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN     4   NaN
# 5      NaN   NaN     1   NaN   NaN   NaN
# 6      NaN   NaN     1     1   NaN   NaN
# 7      NaN   NaN     1   NaN     1   NaN
# 8      NaN   NaN   NaN     1   NaN   NaN
# 9      NaN   NaN     1   NaN   NaN   NaN
# 10     NaN   NaN   330   NaN   NaN   NaN
# 11     NaN   NaN   NaN     1   NaN   NaN
# 12     NaN   NaN     1   NaN   NaN   NaN
# 13       1   NaN   NaN   NaN   NaN   NaN
# 14      10   NaN   NaN   NaN   NaN   NaN
# 15     NaN   NaN   NaN     1   NaN   NaN
# 16       1   NaN   NaN   NaN   NaN   NaN
# 17     NaN     1   NaN   NaN   NaN   NaN
# 18       1   NaN   NaN   NaN   NaN   NaN
# 19       1   NaN   NaN   NaN   NaN   NaN
# 20     NaN   NaN   NaN   NaN     1   NaN
# 21       3   NaN   NaN   NaN   NaN   NaN
# 22       1   NaN   NaN   NaN   NaN   NaN
# 23     NaN   NaN   NaN   NaN     1   NaN
# 24     NaN   NaN    14   NaN   NaN   NaN
# 25       1   NaN   NaN   NaN   NaN   NaN
# 26     NaN     1   NaN   NaN   NaN   NaN
# 27     NaN   NaN   NaN   NaN     1   NaN
# 28       6   NaN   NaN   NaN   NaN   NaN
# 29     NaN   NaN     1   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...
# 8545   NaN     1   NaN   NaN   NaN   NaN
# 8546     1   NaN   NaN   NaN   NaN   NaN
# 8547   NaN     1   NaN   NaN   NaN   NaN
# 8548     5   NaN   NaN   NaN   NaN   NaN
# 8549     2   NaN   NaN   NaN   NaN   NaN
# 8550   NaN   NaN   NaN   NaN  1482   NaN
# 8551   NaN   NaN   NaN   189   NaN   NaN
# 8552   NaN   NaN     8   NaN   NaN   NaN
# 8553     3   NaN   NaN   NaN   NaN   NaN
# 8554   NaN     5   NaN   NaN   NaN   NaN
# 8555     2   NaN   NaN   NaN   NaN   NaN
# 8556     6     1   NaN   NaN   NaN   NaN
# 8557   NaN     1   NaN   NaN   NaN   NaN
# 8558    15    31    15    10   NaN   NaN
# 8559   NaN     1   NaN   NaN   NaN   NaN
# 8560     2   NaN   NaN     1   NaN   NaN
# 8561     9     1   NaN     2     1   NaN
# 8562    17     3   NaN   NaN   NaN   NaN
# 8563   NaN     3   NaN   NaN   NaN   NaN
# 8564   NaN     3   NaN   NaN   NaN   NaN
# 8565   NaN     1   NaN   NaN   NaN   NaN
# 8566   NaN    38   NaN   NaN   NaN   NaN
# 8567   NaN   NaN   NaN   NaN     2   NaN
# 8568   NaN   NaN     6   NaN   NaN   NaN
# 8569   NaN   NaN    20   NaN   NaN   NaN
# 8570   NaN   NaN     1   NaN   NaN   NaN
# 8571     1   NaN   NaN   NaN   NaN   NaN
# 8572     1   NaN   NaN   NaN   NaN   NaN
# 8573     6   NaN   NaN   NaN   NaN   NaN
# 8574    10   NaN   NaN   NaN   NaN   NaN
#
# [8575 rows x 11 columns]

# %%
conf_gimport
# Out:
#      App.                      Taxon                      Term Unit Country  \
# 0       I           Acinonyx jubatus               derivatives  NaN      US
# 1       I           Acinonyx jubatus                      live  NaN      AE
# 2       I           Acinonyx jubatus                      live  NaN      GR
# 3       I           Acinonyx jubatus                      live  NaN      MA
# 4       I           Acinonyx jubatus               skin pieces  NaN      US
# 5       I           Acinonyx jubatus                     skins  NaN      AE
# 6       I           Acinonyx jubatus                     skins  NaN      BW
# 7       I           Acinonyx jubatus                     skins  NaN      GB
# 8       I           Acinonyx jubatus                     skins  NaN      US
# 9       I           Acipenser sturio                  medicine  NaN      US
# 10      I        Addax nasomaculatus                    skulls  NaN      US
# 11      I        Addax nasomaculatus                  trophies  NaN      SA
# 12      I          Aegypius monachus                      live  NaN      XX
# 13      I           Agave parviflora                     seeds  NaN      NZ
# 14      I            Ailurus fulgens                      live  NaN      US
# 15      I         Alligator sinensis                      feet  NaN      US
# 16      I         Alligator sinensis  leather products (large)  NaN      US
# 17      I             Alligator spp.                     heads  NaN      FI
# 18      I             Alligator spp.  leather products (small)  NaN      FI
# 19      I                Aloe hybrid                      live  NaN      US
# 20      I                 Aloe laeta                      live  NaN      US
# 21      I              Aloe suzannae                      live  NaN      US
# 22      I          Alouatta palliata                    skulls  NaN      US
# 23      I             Alouatta pigra             bone carvings  NaN      US
# 24      I       Amazona auropalliata                      live  NaN      SV
# 25      I       Amazona auropalliata                      live  NaN      US
# 26      I        Amazona barbadensis                      live  NaN      US
# 27      I        Amazona barbadensis                      live  NaN      XX
# 28      I       Amazona brasiliensis                      live  NaN      XX
# 29      I            Amazona finschi                      live  NaN      US
# ...   ...                        ...                       ...  ...     ...
# 5187  III      Penelope purpurascens                  trophies  NaN      US
# 5188  III      Platyrrhinus lineatus                 specimens   ml      US
# 5189  III               Potos flavus                      live  NaN      SV
# 5190  III               Potos flavus                      live  NaN      US
# 5191  III               Potos flavus                     skins  NaN      US
# 5192  III          Proteles cristata                  trophies  NaN      US
# 5193  III            Pseudois nayaur                  trophies  NaN      US
# 5194  III          Sarcoramphus papa                  feathers    g      US
# 5195  III          Sarcoramphus papa                  feathers  NaN      US
# 5196  III       Sphiggurus mexicanus                      hair  NaN      US
# 5197  III       Sphiggurus mexicanus                      live  NaN      SV
# 5198  III          Tamandua mexicana                      live  NaN      SV
# 5199  III            Viverra zibetha                      hair  NaN      US
# 5200  III            Viverra zibetha             hair products  NaN      US
# 5201  III         Vulpes bengalensis                 specimens  NaN      US
# 5202  III      Xenochrophis piscator                    bodies  NaN      CS
# 5203  III      Xenochrophis piscator                    bodies  NaN      GT
# 5204  III      Xenochrophis piscator                    bodies  NaN      LV
# 5205  III      Xenochrophis piscator                    bodies  NaN      PL
# 5206  III      Xenochrophis piscator                    bodies  NaN      PT
# 5207  III      Xenochrophis piscator                    bodies  NaN      SK
# 5208  III      Xenochrophis piscator                    bodies  NaN      US
# 5209  III      Xenochrophis piscator               derivatives  NaN      US
# 5210  III      Xenochrophis piscator  leather products (large)  NaN      US
# 5211  III      Xenochrophis piscator                      live  NaN      US
# 5212  III      Xenochrophis piscator                  medicine  NaN      US
# 5213  III      Xenochrophis piscator               skin pieces  NaN      US
# 5214    N              Bubulcus ibis                  feathers  NaN      PL
# 5215    N        Pterapogon kauderni                      live  NaN      PL
# 5216    N  Trachemys scripta elegans                      live  NaN      KW
#
#       2010  2011  2012  2013  2014  2015
# 0        2   NaN   NaN   NaN   NaN   NaN
# 1       20   NaN   NaN   NaN   NaN   NaN
# 2      NaN   1.0   NaN   NaN   NaN   NaN
# 3      NaN   4.0   NaN   NaN   NaN   NaN
# 4      NaN   NaN     1   NaN     4   NaN
# 5      NaN   NaN     1   NaN   NaN   NaN
# 6      NaN   NaN   NaN     1   NaN   NaN
# 7      NaN   NaN     1     1   NaN   NaN
# 8      NaN   NaN     1   NaN     1   NaN
# 9      NaN   NaN   330   NaN   NaN   NaN
# 10     NaN   NaN   NaN     1   NaN   NaN
# 11     NaN   NaN     1   NaN   NaN   NaN
# 12       1   NaN   NaN   NaN   NaN   NaN
# 13      10   NaN   NaN   NaN   NaN   NaN
# 14     NaN   NaN   NaN     1   NaN   NaN
# 15       1   NaN   NaN   NaN   NaN   NaN
# 16     NaN   1.0   NaN   NaN   NaN   NaN
# 17       1   NaN   NaN   NaN   NaN   NaN
# 18       1   NaN   NaN   NaN   NaN   NaN
# 19     NaN   NaN   NaN   NaN     1   NaN
# 20       3   NaN   NaN   NaN   NaN   NaN
# 21       1   NaN   NaN   NaN   NaN   NaN
# 22     NaN   NaN   NaN   NaN     1   NaN
# 23     NaN   NaN    14   NaN   NaN   NaN
# 24       6   NaN   NaN   NaN   NaN   NaN
# 25       1   1.0   NaN   NaN     1   NaN
# 26     NaN   NaN     1   NaN   NaN   NaN
# 27       1   NaN   NaN   NaN   NaN   NaN
# 28       1   NaN   NaN   NaN   NaN   NaN
# 29       1   1.0   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...
# 5187    21   NaN   NaN   NaN   NaN   NaN
# 5188   NaN   2.4   NaN   NaN   NaN   NaN
# 5189     4   NaN   NaN   NaN   NaN   NaN
# 5190   NaN   NaN   NaN     6   NaN   NaN
# 5191   NaN   3.0   NaN   NaN   NaN   NaN
# 5192     1   NaN   NaN   NaN   NaN   NaN
# 5193   NaN   NaN   NaN   NaN     1   NaN
# 5194   NaN   1.0   NaN   NaN   NaN   NaN
# 5195     1   NaN   NaN   NaN   NaN   NaN
# 5196   NaN   1.0   NaN   NaN   NaN   NaN
# 5197     5   NaN   NaN   NaN   NaN   NaN
# 5198     2   NaN   NaN   NaN   NaN   NaN
# 5199   NaN   NaN   NaN   NaN  1482   NaN
# 5200   NaN   NaN   NaN   189   NaN   NaN
# 5201   NaN   NaN     8   NaN   NaN   NaN
# 5202     1   NaN   NaN   NaN   NaN   NaN
# 5203   NaN   NaN   NaN     1   NaN   NaN
# 5204    14  20.0   NaN   NaN   NaN   NaN
# 5205    24   NaN   NaN   NaN   NaN   NaN
# 5206     1   NaN   NaN   NaN   NaN   NaN
# 5207     3   3.0   NaN   NaN   NaN   NaN
# 5208    11  20.0    15    12     1   NaN
# 5209   NaN  45.0   NaN   NaN   NaN   NaN
# 5210   NaN   NaN   NaN   NaN     2   NaN
# 5211   NaN   NaN    26   NaN   NaN   NaN
# 5212   NaN   NaN     1   NaN   NaN   NaN
# 5213     1   NaN   NaN   NaN   NaN   NaN
# 5214     1   NaN   NaN   NaN   NaN   NaN
# 5215     6   NaN   NaN   NaN   NaN   NaN
# 5216    10   NaN   NaN   NaN   NaN   NaN
#
# [5217 rows x 11 columns]

# %%
# TRY MANUAL COPY
# Get img src of the button of corresponding id and type
# print response.geturl()
all_inputs = index.find_all('a', href=True)
# copied_link = "/cites_trade/exports/download?filters[time_range_start]=2015&amp;filters[time_range_end]=2015&amp;filters[exporters_ids][]=all_exp&amp;filters[importers_ids][]=all_imp&amp;filters[sources_ids][]=all_sou&amp;filters[purposes_ids][]=all_pur&amp;filters[terms_ids][]=all_ter&amp;filters[selection_taxon]=taxon&amp;filters[taxon_concepts_ids][]=&amp;filters[reset]=&amp;web_disabled=&amp;filters[report_type]=comptab&amp;filters[csv_separator]=comma" 
print '\nA Tags:', len(all_inputs)
tag_number = 0
for i in all_inputs:
    print '\nTAG', tag_number,':',  i.attrs
    if 'id' in i.attrs:
        if i.attrs['id'] == 'download_genie':
            link = i.get('href')
            print 'MATCH',  i.attrs['id'], link
            print i
            break
#     links = i.find('a')
#     image_src = image.get('src')
#     if 'id' in button.attrs:
#         print button.attrs['id'] == button_id
#         if button.attrs['id'] == button_id:
#             download_button_src = image_src
#             break
#     print 'SRC', download_button_src
#     try:
#         print '\tIMAGE', image
#         print '\tIMAGE SOURCE:', image_src
#     except:
#         pass
#     button_number += 1
# print '\nIMAGE SRC FILE CHOSEN:', download_button_src
# print base_url, index_ref,
# Out:
# A Tags: 13
#
# TAG 0 : {'href': 'http://trade.cites.org/', 'target': '_blank'}
#
# TAG 0 : {'href': '/es/cites_trade/download'}
#
# TAG 0 : {'href': '/fr/cites_trade/download'}
#
# TAG 0 : {'href': '/en/cites_trade/'}
#
# TAG 0 : {'style': 'display:none', 'href': '', 'id': 'view_genie'}
#
# TAG 0 : {'style': 'display:none', 'href': '#', 'id': 'download_genie'}
# MATCH download_genie #
# <a href="#" id="download_genie" style="display:none"></a>

# %%
confcomp.head(50)
# Out:
#     Year App.                        Taxon     Class           Order  \
# 0   2010    I            Aegypius monachus      Aves   Falconiformes
# 1   2010    I         Haliaeetus albicilla      Aves   Falconiformes
# 2   2010    I             Agave parviflora       NaN        Liliales
# 3   2010    I               Alligator spp.  Reptilia      Crocodylia
# 4   2010    I               Alligator spp.  Reptilia      Crocodylia
# 5   2010    I           Alligator sinensis  Reptilia      Crocodylia
# 6   2010    I             Ateles geoffroyi  Mammalia        Primates
# 7   2010    I           Balaena mysticetus  Mammalia         Cetacea
# 8   2010    I           Balaena mysticetus  Mammalia         Cetacea
# 9   2010    I           Balaena mysticetus  Mammalia         Cetacea
# 10  2010    I           Balaena mysticetus  Mammalia         Cetacea
# 11  2010    I           Balaena mysticetus  Mammalia         Cetacea
# 12  2010    I            Balaenoptera spp.  Mammalia         Cetacea
# 13  2010    I            Balaenoptera spp.  Mammalia         Cetacea
# 14  2010    I   Balaenoptera acutorostrata  Mammalia         Cetacea
# 15  2010    I     Balaenoptera bonaerensis  Mammalia         Cetacea
# 16  2010    I     Balaenoptera bonaerensis  Mammalia         Cetacea
# 17  2010    I        Balaenoptera musculus  Mammalia         Cetacea
# 18  2010    I              Boa constrictor  Reptilia       Serpentes
# 19  2010    I     Capricornis sumatraensis  Mammalia    Artiodactyla
# 20  2010    I     Capricornis sumatraensis  Mammalia    Artiodactyla
# 21  2010    I     Capricornis sumatraensis  Mammalia    Artiodactyla
# 22  2010    I         Pantholops hodgsonii  Mammalia    Artiodactyla
# 23  2010    I         Pantholops hodgsonii  Mammalia    Artiodactyla
# 24  2010    I         Pantholops hodgsonii  Mammalia    Artiodactyla
# 25  2010    I         Pantholops hodgsonii  Mammalia    Artiodactyla
# 26  2010    I              Ariocarpus spp.       NaN  Caryophyllales
# 27  2010    I   Ariocarpus kotschoubeyanus       NaN  Caryophyllales
# 28  2010    I  Ariocarpus retusus trigonus       NaN  Caryophyllales
# 29  2010    I      Mammillaria pectinifera       NaN  Caryophyllales
# 30  2010    I              Vicugna vicugna  Mammalia    Artiodactyla
# 31  2010    I              Vicugna vicugna  Mammalia    Artiodactyla
# 32  2010    I               Vultur gryphus      Aves   Falconiformes
# 33  2010    I               Vultur gryphus      Aves   Falconiformes
# 34  2010    I               Vultur gryphus      Aves   Falconiformes
# 35  2010    I               Vultur gryphus      Aves   Falconiformes
# 36  2010    I       Mandrillus leucophaeus  Mammalia        Primates
# 37  2010    I            Mandrillus sphinx  Mammalia        Primates
# 38  2010    I    Piliocolobus rufomitratus  Mammalia        Primates
# 39  2010    I       Semnopithecus entellus  Mammalia        Primates
# 40  2010    I    Semnopithecus schistaceus  Mammalia        Primates
# 41  2010    I      Muntiacus vuquanghensis  Mammalia    Artiodactyla
# 42  2010    I          Cheirogaleus medius  Mammalia        Primates
# 43  2010    I              Caretta caretta  Reptilia      Testudines
# 44  2010    I              Caretta caretta  Reptilia      Testudines
# 45  2010    I              Caretta caretta  Reptilia      Testudines
# 46  2010    I               Chelonia mydas  Reptilia      Testudines
# 47  2010    I               Chelonia mydas  Reptilia      Testudines
# 48  2010    I               Chelonia mydas  Reptilia      Testudines
# 49  2010    I               Chelonia mydas  Reptilia      Testudines
#
#              Family          Genus Importer Exporter Origin  \
# 0      Accipitridae       Aegypius       XX       PT    NaN
# 1      Accipitridae     Haliaeetus       IT       PL     UA
# 2         Agavaceae          Agave       NZ       DE    NaN
# 3     Alligatoridae      Alligator       FI       RU    NaN
# 4     Alligatoridae      Alligator       FI       US    NaN
# 5     Alligatoridae      Alligator       US       CN    NaN
# 6          Atelidae         Ateles       SV       XX    NaN
# 7        Balaenidae        Balaena       DE       US    NaN
# 8        Balaenidae        Balaena       DE       US    NaN
# 9        Balaenidae        Balaena       US       CA     US
# 10       Balaenidae        Balaena       US       CA     US
# 11       Balaenidae        Balaena       US       CA    NaN
# 12  Balaenopteridae   Balaenoptera       CA       US    NaN
# 13  Balaenopteridae   Balaenoptera       US       GH     CI
# 14  Balaenopteridae   Balaenoptera       US       NO    NaN
# 15  Balaenopteridae   Balaenoptera       US       FK     AQ
# 16  Balaenopteridae   Balaenoptera       US       JP     XX
# 17  Balaenopteridae   Balaenoptera       US       FK     AQ
# 18           Boidae            Boa       SV       XX    NaN
# 19          Bovidae    Capricornis       US       LA     XX
# 20          Bovidae    Capricornis       US       LA    NaN
# 21          Bovidae    Capricornis       US       TH    NaN
# 22          Bovidae     Pantholops       AE       IN    NaN
# 23          Bovidae     Pantholops       AE       US    NaN
# 24          Bovidae     Pantholops       AI       GB     XX
# 25          Bovidae     Pantholops       US       CN    NaN
# 26        Cactaceae     Ariocarpus       US       CN    NaN
# 27        Cactaceae     Ariocarpus       US       MX    NaN
# 28        Cactaceae     Ariocarpus       US       MX    NaN
# 29        Cactaceae    Mammillaria       US       MX    NaN
# 30        Camelidae        Vicugna       US       IT     PE
# 31        Camelidae        Vicugna       US       IT     PE
# 32      Cathartidae         Vultur       NZ       AR    NaN
# 33      Cathartidae         Vultur       US       AR    NaN
# 34      Cathartidae         Vultur       US       CO    NaN
# 35      Cathartidae         Vultur       US       PE    NaN
# 36  Cercopithecidae     Mandrillus       GB       CM    NaN
# 37  Cercopithecidae     Mandrillus       GB       CM    NaN
# 38  Cercopithecidae   Piliocolobus       US       UG    NaN
# 39  Cercopithecidae  Semnopithecus       US       NP    NaN
# 40  Cercopithecidae  Semnopithecus       US       NP    NaN
# 41         Cervidae      Muntiacus       US       TH    NaN
# 42   Cheirogaleidae   Cheirogaleus       GB       CN     XX
# 43      Cheloniidae        Caretta       US       CO    NaN
# 44      Cheloniidae        Caretta       US       GH     US
# 45      Cheloniidae        Caretta       US       PE    NaN
# 46      Cheloniidae       Chelonia       BH       AE     XX
# 47      Cheloniidae       Chelonia       NZ       TO    NaN
# 48      Cheloniidae       Chelonia       US       AN    NaN
# 49      Cheloniidae       Chelonia       US       CU    NaN
#
#     Importer reported quantity  Exporter reported quantity  \
# 0                          NaN                           1
# 1                          NaN                           1
# 2                         10.0                         NaN
# 3                          1.0                         NaN
# 4                          1.0                         NaN
# 5                          1.0                         NaN
# 6                          4.0                         NaN
# 7                          NaN                           2
# 8                          NaN                           1
# 9                          2.0                         NaN
# 10                         2.0                         NaN
# 11                         4.0                         NaN
# 12                         NaN                           1
# 13                         8.0                         NaN
# 14                         2.0                         NaN
# 15                         4.0                         NaN
# 16                         2.0                         NaN
# 17                         1.0                         NaN
# 18                        20.0                         NaN
# 19                         1.0                         NaN
# 20                         1.0                         NaN
# 21                         4.0                         NaN
# 22                       227.0                         NaN
# 23                        20.0                         NaN
# 24                         NaN                           1
# 25                         1.0                         NaN
# 26                         3.0                         NaN
# 27                         5.0                         NaN
# 28                         2.0                         NaN
# 29                         3.0                         NaN
# 30                         9.0                         NaN
# 31                         4.0                         NaN
# 32                         1.0                         NaN
# 33                         1.0                         NaN
# 34                         9.0                         NaN
# 35                        10.0                         NaN
# 36                         4.6                         NaN
# 37                         1.8                         NaN
# 38                        20.0                         NaN
# 39                         1.0                         NaN
# 40                         1.0                         NaN
# 41                         1.0                         NaN
# 42                         1.0                         NaN
# 43                         1.0                         NaN
# 44                         1.0                         NaN
# 45                         1.0                         NaN
# 46                         NaN                           1
# 47                         1.0                         NaN
# 48                         1.0                         NaN
# 49                         1.0                         NaN
#
#                         Term Unit Purpose Source
# 0                       live  NaN     NaN      I
# 1                     bodies  NaN     NaN      I
# 2                      seeds  NaN       P      I
# 3                      heads  NaN     NaN      I
# 4   leather products (small)  NaN     NaN      I
# 5                       feet  NaN       P      I
# 6                       live  NaN     NaN      I
# 7                     baleen  NaN       P      I
# 8              bone carvings  NaN       P      I
# 9                     baleen  NaN       P      I
# 10                  carvings  NaN       P      I
# 11             bone carvings  NaN       P      I
# 12                     bones  NaN       P      I
# 13                     bones  NaN       P      I
# 14                      meat  NaN       P      I
# 15                 specimens  NaN       S      I
# 16                      meat  NaN       P      I
# 17                 specimens  NaN       S      I
# 18                      live  NaN     NaN      I
# 19                      meat  NaN       P      I
# 20                     horns  NaN       P      I
# 21                     horns  NaN       P      I
# 22                  garments  NaN     NaN      I
# 23                 specimens  NaN       L      I
# 24                  garments  NaN       E      I
# 25                    skulls  NaN       T      I
# 26                      live  NaN       T      I
# 27                      live  NaN       P      I
# 28                      live  NaN       P      I
# 29                      live  NaN       P      I
# 30                  garments  NaN       T      I
# 31             hair products  NaN       T      I
# 32                  feathers  NaN       P      I
# 33                  feathers  NaN       P      I
# 34                  feathers  NaN       T      I
# 35                     bones  NaN       T      I
# 36                 specimens   ml       S      I
# 37                 specimens   ml       S      I
# 38                 specimens  NaN       S      I
# 39                    skulls  NaN       P      I
# 40                    skulls  NaN       P      I
# 41                    skulls  NaN       P      I
# 42                      live  NaN       Z      I
# 43                    shells  NaN       P      I
# 44                 skeletons  NaN       P      I
# 45                    shells  NaN       P      I
# 46                    skulls  NaN       E      I
# 47                 carapaces  NaN       P      I
# 48                 carapaces  NaN       P      I
# 49                    bodies  NaN       P      I

# %%
# Get levels of the importer and exporter
# levelsof_importer = confcomp['Importer']
confcomp.columns
# Out:
# Index([u'Year', u'App.', u'Taxon', u'Class', u'Order', u'Family', u'Genus',
#        u'Importer', u'Exporter', u'Origin', u'Importer reported quantity',
#        u'Exporter reported quantity', u'Term', u'Unit', u'Purpose', u'Source'],
#       dtype='object')

# %%
# Set Constants
YEAR = 'Year'
APP = 'App'
TAXON = 'Taxon'
CLASS = 'Class'
ORDER = 'Order'
FAMILY = 'Family'
GENUS = 'Genus'
IMPORTER = 'Importer'
EXPORTER = 'Exporter'
ORIGIN = 'Origin'
IMP_QUANTITY = 'Importer reported quantity'
EXP_QUANTITY = 'Exporter reported quantity'
TERM = 'Term'
UNIT = 'Unit'
PURPOSE = 'Purpose'
SOURCE = 'Source'
levelsof_importer = confcomp[IMPORTER].unique()
# print len(levelsof_importer), levelsof_importer
levelsof_exporter = confcomp[EXPORTER].unique()
# print len(levelsof_exporter), levelsof_exporter
levelsof_country = levelsof_exporter.tolist() 
levelsof_country += [i for i in levelsof_importer.tolist() if i not in levelsof_country]
print len(levelsof_country), levelsof_country
country_pairs = []
for c in levelsof_country:
    country_pairs += [(c, i) for i in levelsof_country[1:]
                      if i != c and c != 'XX' and i != 'XX'
                      and (c, i) and (i, c) 
                      not in country_pairs]
print len(country_pairs)
# Out:
# 206 ['PT', 'PL', 'DE', 'RU', 'US', 'CN', 'XX', 'CA', 'GH', 'NO', 'FK', 'JP', 'LA', 'TH', 'IN', 'GB', 'MX', 'IT', 'AR', 'CO', 'PE', 'CM', 'UG', 'NP', 'AE', 'TO', 'AN', 'CU', 'DO', 'EC', 'HT', 'NZ', 'PA', 'TZ', 'VN', 'AU', 'FJ', 'KR', 'MY', 'WS', 'GW', 'CV', 'FM', 'FR', 'GD', 'HN', 'JM', 'MH', 'MZ', 'NI', 'PG', 'PW', 'SV', 'VE', 'VG', 'BS', 'IE', 'CH', 'ES', 'BN', 'CL', 'HK', 'ID', 'IL', 'KH', 'PF', 'SG', 'TW', 'PH', 'SD', 'MU', 'SY', 'BW', 'ML', 'NG', 'NL', 'ZA', 'GT', 'LB', 'BR', 'BE', 'DK', 'MA', 'RO', 'AO', 'CI', 'ER', 'GQ', 'KE', 'LR', nan, 'ZW', 'OM', 'PK', 'QA', 'SO', 'BO', 'CD', 'ZM', 'RW', 'SN', 'CK', 'SE', 'CR', 'YE', 'UA', 'AZ', 'HU', 'IR', 'KZ', 'MN', 'SA', 'UY', 'TR', 'VU', 'SB', 'VC', 'AG', 'AT', 'BM', 'TC', 'CY', 'TT', 'SR', 'GY', 'BZ', 'KY', 'CZ', 'MK', 'BA', 'KG', 'TG', 'KN', 'MG', 'LC', 'NC', 'IQ', 'NF', 'JO', 'GR', 'BG', 'TN', 'ET', 'CG', 'EG', 'PY', 'BJ', 'GN', 'SC', 'AW', 'GE', 'LK', 'KW', 'AL', 'UZ', 'KI', 'MV', 'FI', 'MM', 'NU', 'HR', 'AF', 'IS', 'TL', 'LT', 'TJ', 'MD', 'BB', 'GP', 'LU', 'MO', 'GI', 'CW', 'RS', 'GA', 'BH', 'CC', 'LV', 'DJ', 'SL', 'AM', 'BI', 'MW', 'BD', 'LI', 'SI', 'EE', 'CF', 'MQ', 'BT', 'NE', 'SX', 'MC', 'MR', 'LS', 'SK', 'VA', 'GM', 'TM', 'LY', 'BY', 'SZ', 'AI', 'DZ', 'CS', 'MT']
# 20911

# %%
# Count country pairs
country_pairs_pd= confcomp.groupby([IMPORTER, EXPORTER, CLASS]).size().sort_values(ascending=False)
print 'country_pairs_pd:\n', country_pairs_pd
country_pairs_pd.index
# Out:
# country_pairs_pd:
# Importer  Exporter  Class
# US        ID        Anthozoa          588
#           MX        Reptilia          389
#           CA        Mammalia          388
#           IT        Reptilia          301
#           TH        Reptilia          238
#           CN        Mammalia          216
#           MX        Aves              202
#           FR        Reptilia          199
#           GB        Reptilia          188
#           VN        Mammalia          177
#           ID        Reptilia          173
#           ZA        Mammalia          168
#           MX        Mammalia          168
#           CA        Aves              150
#           HK        Reptilia          149
#           CN        Reptilia          146
#           GB        Mammalia          142
#           AU        Anthozoa          128
#                     Reptilia          116
#           CA        Reptilia          115
#           CH        Reptilia          113
#           TO        Anthozoa          105
#           TH        Mammalia           99
#           VN        Reptilia           93
#           FJ        Anthozoa           93
#           ZW        Mammalia           88
#           ID        Mammalia           85
#           CN        Actinopterygii     81
#           SV        Reptilia           79
#           NG        Reptilia           77
#                                      ...
#           KI        Mammalia            1
# NO        SO        Elasmobranchii      1
#           SG        Actinopterygii      1
#           RU        Mammalia            1
#           RO        Mammalia            1
# US        KW        Elasmobranchii      1
# NO        PE        Reptilia            1
#           NL        Aves                1
#           MY        Actinopterygii      1
#           ZA        Reptilia            1
# US        JO        Anthozoa            1
# NZ        AG        Anthozoa            1
#           CA        Aves                1
# US        ID        Elasmobranchii      1
# NZ        CL        Anthozoa            1
#           CK        Mammalia            1
#                     Insecta             1
# US        IN        Elasmobranchii      1
#                     Reptilia            1
# NZ        CA        Elasmobranchii      1
#                     Actinopterygii      1
# US        IT        Bivalvia            1
# NZ        BN        Reptilia            1
# US        IQ        Aves                1
#                     Reptilia            1
#           IR        Aves                1
# NZ        AU        Aves                1
# US        IR        Reptilia            1
# NZ        AR        Mammalia            1
# TR        BE        Amphibia            1
# dtype: int64
# MultiIndex(levels=[[u'AE', u'AI', u'AN', u'AO', u'AR', u'AT', u'AU', u'AW', u'AZ', u'BB', u'BD', u'BE', u'BG', u'BH', u'BM', u'BR', u'BS', u'BT', u'BW', u'BY', u'BZ', u'CA', u'CD', u'CH', u'CI', u'CL', u'CN', u'CO', u'CS', u'CZ', u'DE', u'DK', u'DZ', u'EC', u'EG', u'ES', u'FI', u'FJ', u'FR', u'GB', u'GE', u'GP', u'GR', u'GT', u'HK', u'HR', u'HU', u'ID', u'IE', u'IL', u'IN', u'IQ', u'IR', u'IT', u'JO', u'JP', u'KE', u'KR', u'KW', u'KZ', u'LA', u'LB', u'LI', u'LT', u'LU', u'LV', u'MA', u'MC', u'MG', u'MO', u'MT', u'MU', u'MW', u'MX', u'MY', u'NI', u'NL', u'NO', u'NZ', u'OM', u'PA', u'PE', u'PH', u'PK', u'PL', u'PT', u'PY', u'QA', u'RO', u'RU', u'SA', u'SE', u'SG', u'SK', u'SR', u'SV', u'SZ', u'TG', u'TH', u'TN', u'TR', u'TW', u'UA', u'UG', u'US', u'UY', u'UZ', u'VE', u'VN', u'XX', u'ZA', u'ZM'], [u'AE', u'AF', u'AG', u'AL', u'AM', u'AN', u'AO', u'AR', u'AT', u'AU', u'AW', u'AZ', u'BA', u'BB', u'BD', u'BE', u'BG', u'BH', u'BI', u'BJ', u'BM', u'BN', u'BO', u'BR', u'BS', u'BT', u'BW', u'BY', u'BZ', u'CA', u'CC', u'CD', u'CF', u'CG', u'CH', u'CI', u'CK', u'CL', u'CM', u'CN', u'CO', u'CR', u'CU', u'CV', u'CW', u'CY', u'CZ', u'DE', u'DJ', u'DK', u'DO', u'EC', u'EE', u'EG', u'ER', u'ES', u'ET', u'FI', u'FJ', u'FK', u'FM', u'FR', u'GA', u'GB', u'GD', u'GE', u'GH', u'GI', u'GM', u'GN', u'GP', u'GQ', u'GR', u'GT', u'GW', u'GY', u'HK', u'HN', u'HR', u'HT', u'HU', u'ID', u'IE', u'IL', u'IN', u'IQ', u'IR', u'IS', u'IT', u'JM', u'JO', u'JP', u'KE', u'KG', u'KH', u'KI', u'KN', u'KR', u'KW', u'KY', u'KZ', u'LA', u'LB', u'LC', u'LI', u'LK', u'LR', u'LS', u'LT', u'LU', u'LV', u'LY', u'MA', u'MC', u'MD', u'MG', u'MH', u'MK', u'ML', u'MM', u'MN', u'MO', u'MQ', u'MR', u'MU', u'MV', u'MW', u'MX', u'MY', u'MZ', u'NC', u'NE', u'NF', u'NG', u'NI', u'NL', u'NO', u'NP', u'NU', u'NZ', u'OM', u'PA', u'PE', u'PF', u'PG', u'PH', u'PK', u'PL', u'PT', u'PW', u'PY', u'QA', u'RO', u'RS', u'RU', u'RW', u'SA', u'SB', u'SC', u'SD', u'SE', u'SG', u'SI', u'SK', u'SL', u'SN', u'SO', u'SR', u'SV', u'SX', u'SY', u'SZ', u'TC', u'TG', u'TH', u'TJ', u'TL', u'TM', u'TN', u'TO', u'TR', u'TT', u'TW', u'TZ', u'UA', u'UG', u'US', u'UY', u'UZ', u'VA', u'VC', u'VE', u'VG', u'VN', u'VU', u'WS', u'XX', u'YE', u'ZA', u'ZM', u'ZW'], [u'Actinopterygii', u'Amphibia', u'Anthozoa', u'Arachnida', u'Aves', u'Bivalvia', u'Elasmobranchii', u'Gastropoda', u'Hirudinoidea', u'Holothuroidea', u'Hydrozoa', u'Insecta', u'Mammalia', u'Reptilia']],
#            labels=[[104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 21, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 109, 104, 104, 104, 104, 78, 104, 104, 104, 53, 104, 26, 104, 104, 104, 104, 104, 104, 104, 104, 104, 44, 104, 104, 104, 104, 90, 104, 104, 104, 104, 104, 21, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 6, 104, 104, 87, 0, 104, 104, 104, 104, 38, 104, 104, 104, 104, 21, 55, 104, 104, 26, 104, 104, 104, 104, 104, 104, 104, 104, 104, 78, 104, 104, 44, 104, 104, 104, 104, 39, 104, 104, 104, 104, 104, 104, 104, 39, 104, 104, 104, 104, 104, 104, 100, 38, 104, 104, 104, 104, 104, 104, 104, 95, 104, 104, 104, 104, 104, 104, 104, 101, 104, 104, 15, 104, 104, 104, 73, 5, 104, 89, 78, 104, 104, 104, 104, 93, 57, 104, 104, 104, 104, 35, 104, 76, 73, 78, 104, 104, 104, 104, 104, 39, 55, 104, 104, 13, 58, 78, 104, 73, 104, 104, 104, 104, 90, 104, 104, 109, 53, 104, 78, 104, 104, 78, 104, 104, 104, 104, 104, 104, 104, 15, 104, 23, 30, 104, 78, 78, 104, 18, 104, 104, 39, 104, 104, 57, 104, 104, 104, 1, 104, 30, 104, 104, 98, 23, 104, 104, 0, 101, 104, 104, 104, 104, 104, 78, 104, 55, 51, 104, 104, 104, 104, 104, 104, 104, 104, 104, 77, 104, 38, 104, 104, 104, 82, 104, 78, 78, 78, 104, 104, 39, 104, 1, 104, 104, 104, 104, 104, 78, 104, 95, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 78, 104, 65, 104, 104, 78, 13, 17, 104, 78, 104, 104, 78, 104, 104, 104, 104, 104, 0, 13, 78, 104, 104, 104, 104, 109, 104, 109, 104, 104, 104, 0, 29, 104, 104, 104, 104, 91, 78, 104, 104, 104, 84, 6, 104, 78, 78, 104, 95, 104, 58, 104, 74, 104, 104, 104, 77, 21, 104, 104, 89, 104, 78, 104, 104, 104, 104, 42, 65, 104, 78, 104, 77, 67, 104, 104, 58, 29, 93, 78, 104, 104, 104, 104, 45, 104, 14, 104, 5, 78, 104, 104, 104, 104, 82, 0, 104, 104, 104, 78, 104, 104, 104, 78, 78, 104, 104, 104, 23, 104, 85, 104, 78, 78, 104, 78, 0, 104, 104, 104, 104, 104, 104, 104, 104, 104, 92, 104, 104, 104, 104, 104, 104, 78, 100, 104, 104, 104, 104, 104, 78, 89, 104, 104, 100, 104, 104, 78, 104, 84, 104, 104, 78, 78, 84, 78, 104, 104, 84, 84, 102, 68, 104, 104, 17, 104, 104, 11, 11, 104, 104, 104, 64, 6, 65, 6, 104, 104, 5, 5, 29, 69, 5, 72, 5, 104, 53, 104, 51, 104, 104, 30, 29, 104, 104, 36, 37, 104, 104, 27, 104, 51, 23, 104, 39, 23, 104, 39, 39, 104, 104, 104, 104, 29, 110, 77, 0, 77, 78, 104, 104, 104, 0, 78, 107, 104, 104, 104, 78, 78, 78, 104, 78, 77, 104, 78, 77, 110, 78, 5, 77, 104, 104, 104, 104, 104, 110, 0, 27, 29, 26, 29, 89, 0, 0, 29, 29, 23, 0, 91, 5, 91, 92, 5, 5, 97, 5, 4, 98, 1, 0, 98, 93, 6, 0, 98, 100, 0, 0, 19, 101, 20, 21, 92, 78, 84, 29, 77, 78, 78, 78, 102, 77, 77, 77, 78, 77, 74, 73, 73, 72, 78, 77, 77, 66, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 78, 67, 65, 30, 87, 84, 39, 39, 84, 38, 38, 38, 39, 87, 36, 88, 30, 30, 30, 39, 78, 82, 55, 65, 63, 58, 58, 57, 57, 55, 84, 55, 47, 84, 44, 43, 39, 111, 0, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 102, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 104, 110, 104, 104, 104, 104, 104, 104, 104, 104, 29, 36, 29, 36, 29, 36, 29, 104, 37, 37, 36, 29, 29, 35, 104, 104, 30, 104, 30, 30, 37, 30, 30, 104, 30, 30, 29, 31, 31, 104, 32, 104, 29, 29, 33, 34, 35, 29, 104, 35, 104, 29, 102, 104, 104, 37, 104, 53, 104, 53, 53, 52, 104, 104, 51, 50, 49, 49, 49, 48, 48, 47, 46, 53, 54, 54, 55, 57, 57, 57, 56, 55, 104, 55, 104, 55, 55, 55, 104, 104, 55, 55, 55, 104, 45, 104, 38, 104, 39, 104, 29, 39, 38, 104, 38, 39, 104, 38, 104, 104, 38, 38, 104, 104, 104, 44, 40, 44, 44, 44, 43, 43 ...
#            names=[u'Importer', u'Exporter', u'Class'])

# %%
confcomp.head(20)
# Out:
#     Year App.                       Taxon     Class          Order  \
# 0   2010    I           Aegypius monachus      Aves  Falconiformes
# 1   2010    I        Haliaeetus albicilla      Aves  Falconiformes
# 2   2010    I            Agave parviflora       NaN       Liliales
# 3   2010    I              Alligator spp.  Reptilia     Crocodylia
# 4   2010    I              Alligator spp.  Reptilia     Crocodylia
# 5   2010    I          Alligator sinensis  Reptilia     Crocodylia
# 6   2010    I            Ateles geoffroyi  Mammalia       Primates
# 7   2010    I          Balaena mysticetus  Mammalia        Cetacea
# 8   2010    I          Balaena mysticetus  Mammalia        Cetacea
# 9   2010    I          Balaena mysticetus  Mammalia        Cetacea
# 10  2010    I          Balaena mysticetus  Mammalia        Cetacea
# 11  2010    I          Balaena mysticetus  Mammalia        Cetacea
# 12  2010    I           Balaenoptera spp.  Mammalia        Cetacea
# 13  2010    I           Balaenoptera spp.  Mammalia        Cetacea
# 14  2010    I  Balaenoptera acutorostrata  Mammalia        Cetacea
# 15  2010    I    Balaenoptera bonaerensis  Mammalia        Cetacea
# 16  2010    I    Balaenoptera bonaerensis  Mammalia        Cetacea
# 17  2010    I       Balaenoptera musculus  Mammalia        Cetacea
# 18  2010    I             Boa constrictor  Reptilia      Serpentes
# 19  2010    I    Capricornis sumatraensis  Mammalia   Artiodactyla
#
#              Family         Genus Importer Exporter Origin  \
# 0      Accipitridae      Aegypius       XX       PT    NaN
# 1      Accipitridae    Haliaeetus       IT       PL     UA
# 2         Agavaceae         Agave       NZ       DE    NaN
# 3     Alligatoridae     Alligator       FI       RU    NaN
# 4     Alligatoridae     Alligator       FI       US    NaN
# 5     Alligatoridae     Alligator       US       CN    NaN
# 6          Atelidae        Ateles       SV       XX    NaN
# 7        Balaenidae       Balaena       DE       US    NaN
# 8        Balaenidae       Balaena       DE       US    NaN
# 9        Balaenidae       Balaena       US       CA     US
# 10       Balaenidae       Balaena       US       CA     US
# 11       Balaenidae       Balaena       US       CA    NaN
# 12  Balaenopteridae  Balaenoptera       CA       US    NaN
# 13  Balaenopteridae  Balaenoptera       US       GH     CI
# 14  Balaenopteridae  Balaenoptera       US       NO    NaN
# 15  Balaenopteridae  Balaenoptera       US       FK     AQ
# 16  Balaenopteridae  Balaenoptera       US       JP     XX
# 17  Balaenopteridae  Balaenoptera       US       FK     AQ
# 18           Boidae           Boa       SV       XX    NaN
# 19          Bovidae   Capricornis       US       LA     XX
#
#     Importer reported quantity  Exporter reported quantity  \
# 0                          NaN                           1
# 1                          NaN                           1
# 2                           10                         NaN
# 3                            1                         NaN
# 4                            1                         NaN
# 5                            1                         NaN
# 6                            4                         NaN
# 7                          NaN                           2
# 8                          NaN                           1
# 9                            2                         NaN
# 10                           2                         NaN
# 11                           4                         NaN
# 12                         NaN                           1
# 13                           8                         NaN
# 14                           2                         NaN
# 15                           4                         NaN
# 16                           2                         NaN
# 17                           1                         NaN
# 18                          20                         NaN
# 19                           1                         NaN
#
#                         Term Unit Purpose Source
# 0                       live  NaN     NaN      I
# 1                     bodies  NaN     NaN      I
# 2                      seeds  NaN       P      I
# 3                      heads  NaN     NaN      I
# 4   leather products (small)  NaN     NaN      I
# 5                       feet  NaN       P      I
# 6                       live  NaN     NaN      I
# 7                     baleen  NaN       P      I
# 8              bone carvings  NaN       P      I
# 9                     baleen  NaN       P      I
# 10                  carvings  NaN       P      I
# 11             bone carvings  NaN       P      I
# 12                     bones  NaN       P      I
# 13                     bones  NaN       P      I
# 14                      meat  NaN       P      I
# 15                 specimens  NaN       S      I
# 16                      meat  NaN       P      I
# 17                 specimens  NaN       S      I
# 18                      live  NaN     NaN      I
# 19                      meat  NaN       P      I
