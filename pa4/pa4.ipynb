# %%
# Rebeccah Duvoisin
# Assignment 4
from __future__ import  division
import os
import sys
import re as re
import time
from urllib import urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import datetime as dt
import json
base_url = "https://en.wikipedia.org"
index_ref  = "/wiki/List_of_accidents_and_incidents_involving_commercial_aircraft"
index_html = urlopen(base_url + index_ref)
# Parsed version of html - that is what a BeautifulSoup object is.
index = BeautifulSoup(index_html, 'lxml')

# %%
# Create functions and classes
class Crash(object):
    '''
    Initiates a class to hold attributes of a scraped Wiki crash;
    - *link
    - *li object
    - *year
    - *date
    - *brief
    - place
    - crew
    - passengers
    - fatalities
    - survivors
    - registration
    - origin
    - destination
    '''

    def __init__(self, dictionary, li_object=None):
        self.__link = dictionary['link']
        self.__li = li_object
        self._year = dictionary['year']  # Public; mutable anytime.
        self._date = dictionary['date']  # Public; mutable anytime.
        self._brief = dictionary['brief']  # Public; mutable anytime.
        self._place = None
        self._crew = None
        self._passengers = None
        self._fatalities = None
        self._survivors = None
        self._registration = None
        self._origin = None
        self._destination = None
        self._data = None


    @property
    def link(self):
        return self.__link

    @property
    def li(self):
        return self.__li

    @property
    def year(self):
        '''Accident Year.'''
        return self._year

    @property
    def date(self):
        '''Accident Date (Month and Day).'''
        return self._date

    @date.setter
    def date(self, newdate):
        self._date = newdate

    @property
    def brief(self):
        '''Brief description of the accident.'''
        return self._brief

    @property
    def place(self):
        '''Location of the accident.'''
        return self._place

    @place.setter
    def place(self, place_string):
        self._place = place_string

    @property
    def crew(self):
        '''
        Number of crew members aboard: maybe a string
        or a list of strings if involving multiple
        aircraft.
        '''
        return self._crew

    @crew.setter
    def crew(self, crew_string):
        self._crew = crew_string

    @property
    def passengers(self):
        '''
        Number of passengers aboard: maybe a string
        or a list of strings if involving multiple
        aircraft.
        '''
        return self._passengers

    @passengers.setter
    def passengers(self, passengers_string):
        self._passengers = passengers_string

    @property
    def fatalities(self):
        '''Number of fatalities.'''
        return self._fatalities

    @fatalities.setter
    def fatalities(self, fatalities_string):
        self._fatalities = fatalities_string

    @property
    def survivors(self):
        '''Number of survivors.'''
        return self._survivors

    @survivors.setter
    def survivors(self, survivors_string):
        self._survivors = survivors_string

    @property
    def registration(self):
        '''
        Flight egistration code: maybe a string
        or a list of strings if involving multiple
        aircraft.
        '''
        return self._registration

    @registration.setter
    def registration(self, registration_string):
        self._registration = registration_string

    @property
    def origin(self):
        '''
        Flight origin: maybe a string
        or a list of strings if involving multiple
        aircraft.
        '''
        return self._origin

    @origin.setter
    def origin(self, origin_string):
        self._origin = origin_string

    @property
    def destination(self):
        '''
        Flight destination: maybe a string
        or a list of strings if involving multiple
        aircraft.
        '''
        return self._destination

    @destination.setter
    def destination(self, destination_string):
        self._destination = destination_string

    @property
    def data(self):
        '''Raw data list of table tuples.'''
        return self._data

    @data.setter
    def data(self, data_list):
        self._data = data_list

    def get_attribute(self, string_name):
        if string_name == 'link':
            return self.__link
        elif string_name == 'li':
            return self.__li
        elif string_name == 'year':
            return self._year
        elif string_name == 'date':
            return self._date
        elif string_name == 'brief':
            return self._brief
        elif string_name == 'place':
            return self._place
        elif string_name == 'crew':
            return self._crew
        elif string_name == 'passengers':
            return self._passengers
        elif string_name == 'fatalities':
            return self._fatalities
        elif string_name == 'survivors':
            return self._survivors
        elif string_name == 'registration':
            return self._registration
        elif string_name == 'origin':
            return self._origin
        elif string_name == 'destination':
            return self._destination
        elif string_name == 'data':
            return self._data
        else:
            print 'Enter valid attribute name!'


def parse_crashes_to_dict(all_header3):
    '''
    Input: a group of h3 headers that contain hierarchical html lists.
    Returns: A dictionary of years to dictionaries of dates and link
        information:
        -date: the date of the crash.
        -link: the link to further info on the crash.
        -brief: a brief description of the accident.
        -place: the location of the crash.
    '''
    header_lists_year_dics = {}
    for i in range(len(all_header3)):
        this_header = all_header3[i]
        this_header.next_sibling.next_sibling
        is_911 = False
        if not this_header.span:
            return header_lists_year_dics
        year = int(this_header.span.get('id'))
        is_ul = this_header
        while is_ul.name != 'ul':
            is_ul = is_ul.next_sibling
        listings = [is_ul.contents[i] for i in range(len(is_ul.contents[:-1])) if i%2>0]
        for listing in listings:
            header_li = listing
            if len(header_li.findChildren('li')) > 0:
                header_date = []
                header_brief = []
                for subbullet_li in header_li.findChildren('li'):
                    has_same_date = False
                    if not subbullet_li.next_element.name:
                        is_date = re.match('([1-9]+)', subbullet_li.next_element.split()[1])
                        if is_date:
                            strip_date = subbullet_li.next_element[:-2].strip()
                        else:
                            strip_date = header_li.next_element[:-2].strip()
                            has_same_date = True
                    else:
                        strip_date = header_li.next_element[:-2].strip()
                        is_911 = True
                        has_same_date = True
                    sub_dater = re.match('(^\w+ \w+)(.*)', strip_date)
                    sub_date = sub_dater.group(1)
                    if not subbullet_li.next_element.name:
                        header_date.append(sub_date)
                        if has_same_date:
                            header_brief = subbullet_li.contents[-1].encode('ascii', 'ignore')
                        else:
                            sub_text = sub_dater.group(2).strip().encode('ascii', 'ignore')
                            header_brief.append(re.search('(\w+)(.*)', sub_text).group(0).encode('ascii', 'ignore'))
                    else:
                        header_brief = subbullet_li.contents[-1].encode('ascii', 'ignore')
                        new_bullet_from_li(subbullet_li, header_lists_year_dics, year, sub_date, header_brief)
            else:
                strip_date = header_li.next_element[:-2].strip()
                header_dater = re.match('(^\w+ \w+)(.*)', strip_date)
                header_date = header_dater.group(1)
                header_text = header_li.get_text()
                header_brief = re.sub(strip_date, '', header_text, 1).strip().encode('ascii', 'ignore')
            if not is_911:
                new_bullet_from_li(header_li, header_lists_year_dics, year, header_date, header_brief)
    return header_lists_year_dics


def new_bullet_from_li(header_li, header_lists_year_dics=dict,
                       year=None, header_date=None, header_brief=None):
    '''
    Helper function for parse_crashes_to_dict.

    Inputs: One html 'li' list, and other information
    pertaining to it.

    Returns: A dictionary of years to dictionaries for the li.
        -date: the date of the crash.
        -link: the link to further info on the crash.
        -brief: a brief description of the accident.
        -place: the location of the crash.
    '''
    is_a = header_li
    while is_a.name != 'a':
        is_a = is_a.next_element
    header_href = is_a.get('href')
    header_bullet = {'year': year, 'date': None, 'link': None, 'brief': None, 'place':None}
    header_bullet['date'] = header_date
    header_bullet['link'] = header_href
    header_bullet['brief'] = header_brief
    header_dict = Crash(header_bullet, header_li)
    empty_list = []
    header_lists_year_dics[year] = \
        header_lists_year_dics.get(year, {})
    if isinstance(header_date, list):
        for each_date in header_date:
            header_lists_year_dics[year][each_date] = \
                header_lists_year_dics[year].get(each_date, empty_list)
            if header_lists_year_dics[year][each_date]:
                header_lists_year_dics[year][each_date].append(header_dict)
            else:
                header_lists_year_dics[year][each_date] = [header_dict]
    else:
        header_lists_year_dics[year][header_date] = \
            header_lists_year_dics[year].get(header_date, empty_list)
        if header_lists_year_dics[year][header_date]:
            header_lists_year_dics[year][header_date].append(header_dict)
        else:
            header_lists_year_dics[year][header_date] = [header_dict]


def dict_todataframe(crash_dict):
    '''
    Helper function for transforming dictionary into matrix.
    Inputs: One crash dictionary of {years:dates:[crash_objects]}
    Returns: A pandas DataFrame.
    '''
    month_dict = {1: 'January', 2:'February', 3:'March', 4:'April',
                  5:'May', 6: 'June', 7: 'July', 8: 'August', 9:'September',
                  10: 'October', 11:'November', 12:'December'}

    dict_month = {}
    for k in month_dict.keys():
        dict_month[month_dict[k]] = k
    dates = []
    events = []
    for year in crash_dict.keys():
        string_dates = []
        crash_objects = []
        for date in crash_dict[year].keys():
            month = dict_month[str(date.split()[0])]
            day = int(str(date.split()[1]))
            crash_date = str(year) + str(month).zfill(2) + str(day).zfill(2)
            for c_ob in range(len(crash_dict[year][date])):
                string_dates.append(crash_date)
                crash_objects.append(crash_dict[year][date][c_ob])
        dates.extend(string_dates)
        events.extend(crash_objects)
    return pd.DataFrame({'Date':dates, 'Crash': events})


def fix_date_lists(row):
    '''
    Edits the date of the Crash objects
    according to the 'Date' column.
    '''
    row[CRASH].date = row[DATE]


def fix_base_link(row):
    '''Return a LINK column with full address'''
    newlink = base_url + row[LINK]
    row[LINK] = newlink
    return row[LINK]


def fix_unicode_lists(row, COLUMN, INDEX='Index_Copy'):
    '''Replaces all lists in COLUMN with a single value'''
    if isinstance(row[COLUMN], list):
        if row[COLUMN]:
            print '_N = {} ({}):'.format(row[INDEX], row[DATE]), COLUMN, \
                  '{} items:'.format(len(row[COLUMN])), row[COLUMN]
            if row[INDEX] % 2 == 0:
                selected_item = re.sub(r'(\[\d+\])', '', row[COLUMN][0])
            else:
                selected_item = re.sub(r'(\[\d+\])', '', row[COLUMN][-1])
            print "\t>>", selected_item
        else:
            selected_item = np.nan
        row[COLUMN] = selected_item
        return row[COLUMN]
    else:
        row[COLUMN] = row[COLUMN]
        return row[COLUMN]


def make_dataframe(pattern='h3',
                   DATE='Date', CRASH='Crash',
                   LINK='Link', BRIEF='Brief'):
    '''
    Make a pandas dataframe from a BeautifulSoup index,
    and a starting pattern.

    Inputs: A BeautifulSoup object to parse and initial pattern,
    such as a header type, as a starting node.

    Calls parse_crashes_to_dict to assemble a dictionary
    of parsed links of interest.

    Returns: A pandas dataframe of Crash objects, from which
        following columns are also derived from the Crash attributes:
        - DATE, from CRASH.date,
        - LINK, from CRASH.link,
        - BRIEF, from CRASH.brief
    '''
    print '\nQUESTION 1: Part A\n Parsing data into dictionary...'
    all_headers = index.find_all(pattern)
    crash_dict = parse_crashes_to_dict(all_headers)
    print '\nBuilding dataframe from dictionary...'
    crashes = dict_todataframe(crash_dict)
    crashes[DATE] = pd.to_datetime(crashes[DATE])
    crashes[LINK] = crashes[CRASH].apply(lambda c: c.link)
    crashes[BRIEF] = crashes[CRASH].apply(lambda c: c.brief)
    crashes.apply(fix_date_lists, axis=1)
    print '\nDataframe built:\n Shape:', \
            crashes.shape, '\n Columns:', \
            crashes.columns, '\n Head 10:\n', \
            crashes.head(10)
    return crashes


def grab_link_like_person(url, interval=4):
    '''
    Clicks a url address and sets of timer
    to ensure a specified rate limit for url requests
    to the target web server.

    Returns an opened url page to scrape  content.
    '''
    html = urlopen(url)
    # source_code = requests.get(url)
    time.sleep(interval)
    return html


def collapse_table(chosen_table):
    '''
    Helper for scrape_link:
    Input: an html table object
    Returns:
        - raw_data: a list of raw string tables cells for archive,
        - data: a list of processed string tables cells
            to be used in saving contents to Crash attributes.
    '''
    table_rows = chosen_table.find_all('tr')
    row_tuples = [r.find_all(['th','td']) for r in table_rows]
    data = []
    raw_data = []
    # Compile tuples from table rows
    for row in row_tuples[2:]:
        for i in range(len(row)):
            row[i] = row[i].get_text().strip().encode('ascii', 'ignore')
        if row[0] =='Site':
            raw_data.append(row)
            row[1] = row[1].split('\n')[0]
            data.append(row)
        elif row[0] in ['Destination', 'Flight origin',
                        'Operator', 'Registration']:
            row[1] = re.sub(r'(\[\d+\])','', row[1])
            raw_data.append(row)
            data.append(row)
        elif row[0] in ['Crew', 'Passengers', 'Survivors',
                              'Fatalities', 'Total survivors',
                              'Total fatalities']:
            raw_data.append(row)
            row[1] = re.sub(r'(\[\d+\])','', row[1])
            pattern = re.compile('(\D*)(\d*)')
            anymatches = re.match(pattern, row[1])
            if anymatches.groups()[1]:
                row[1] = int(anymatches.groups()[1])
            else:
                if (row[1] == 'all' or row[1] == '(all)'):
                    row[1] = np.nan
                else:
                    row[1] = 0
            data.append(row)
        else:
            pass
    return raw_data, data


def scrape_link(crash_links, verbose=True):
    '''
    Input: a pandas dataframe of Crash objects.

    Calls grab_link_like_person on each Crash object's
    link attribute.

    Scrapes the first table of class 'infobox' from
    the link into a list of cleaned field-value
    texts for each row in table.

    Builds a flight dictionary from the valid field-value list,
    into key:value pairs.

    Stores each valid key-value pair into the crash_object
    under the appropriate attribute:
        -Number of passengers
        -Number of crew
        -Number of fatalities
        -Number of survivors
        -Registration
        -Flight origin
        -Destination
    '''
    print '\nPart B. \nScrape data from links and save to Crash object attributes...\n'
    count = -1
    for crash_link in crash_links:
        count += 1
        # Turn the link into an html file
        link_html = grab_link_like_person(base_url + crash_link.link)
        crash_html = BeautifulSoup(link_html, 'lxml')
        all_tables = crash_html.find_all('table')
        chosen_table = None
        right_class = 'infobox'
        # Select the table of the correct class to scrape
        while not chosen_table:
            for tab in all_tables:
                key = 'class'
                if key in tab.attrs:
                    if right_class in tab[key]:
                        chosen_table = tab
                        break
        # Collect data from table
        raw_data, data = collapse_table(chosen_table)
        # Save raw data table to crash object
        crash_link.data = raw_data
        paired_data = [[element[0], element[1]] for element in data if len(element) > 1]
        # Compile data dictionary from data tuples
        flight_dict = {}
        for k, v in paired_data:
            dict_list = flight_dict.keys()
            if k in dict_list:
                if k in ['Crew', 'Passengers', 'Survivors',
                         'Fatalities', 'Total survivors',
                         'Total fatalities']:
                    summation = flight_dict[k]
                    if summation:
                        summation += v
                    else:
                        summation = v
                    flight_dict[k] = summation
                else:
                    make_list = [flight_dict[k]]
                    make_list.append(v)
                    flight_dict[k] = make_list
            else:
                flight_dict[k] = v
        # Store new attributes to crash object
        if 'Site' in flight_dict.keys():
            crash_link.place = flight_dict['Site']
        if 'Crew' in flight_dict.keys():
            crash_link.crew = flight_dict['Crew']
        if 'Passengers' in flight_dict.keys():
            crash_link.passengers = flight_dict['Passengers']
        if 'Fatalities' in flight_dict.keys():
            crash_link.fatalities = flight_dict['Fatalities']
        if 'Total fatalities' in flight_dict.keys():
            crash_link.fatalities = flight_dict['Total fatalities']
        if 'Survivors' in flight_dict.keys():
            crash_link.survivors = flight_dict['Survivors']
        if 'Total survivors' in flight_dict.keys():
            crash_link.survivors = flight_dict['Total survivors']
        if 'Operator' in flight_dict.keys():
            crash_link.registration = flight_dict['Operator']
        if 'Registration' in flight_dict.keys():
            crash_link.registration = flight_dict['Registration']
        if 'Flight origin' in flight_dict.keys():
            crash_link.origin = flight_dict['Flight origin']
        if 'Destination' in flight_dict.keys():
            crash_link.destination = flight_dict['Destination']
        if verbose:
            if verbose == 'light':
                if count % 10 == 0:
                    print count, ':', crash_link.date, crash_link.year
            else:
                print count, ':', crash_link.date,  crash_link.year, crash_link.link, 'Place =', crash_link.place, ',', crash_link.fatalities, 'killed.'
    print '...all data scraped.'


def attributes_to_columns(crash_data, CRASH='Crash', PLACE='Place', CREW='Crew',
                          PASSENGERS='Passengers', FATALITIES='Fatalities',
                          SURVIVORS='Survivors', REGISTRATION='Registration',
                          ORIGIN='Origin', DESTINATION='Destination', DATA ='Raw_Data',
                          attributes={}
                          ):
    '''
    Uses apply(lambda crash_object.get_attribute(name)) to populate
    additional columns to the dataframe.
    Inputs:
        - a dataframe that includes a column of
          Crash objects,
        - a dictionary of attributes to extract from
          the Crash objects column.
    Returns:
        - a dataframe with the additional
          row-wise attribute content.
    '''
    if not attributes:
        attributes = {'place': PLACE,
                      'crew': CREW,
                      'passengers': PASSENGERS,
                      'survivors': SURVIVORS,
                      'fatalities': FATALITIES,
                      'registration': REGISTRATION,
                      'origin': ORIGIN,
                      'destination': DESTINATION,
                      'data': DATA
                      }
    for k in attributes:
        crash_data[attributes[k]] = \
        crash_data[CRASH].apply(lambda c: c.get_attribute(k))
    print '\nPopulated attributes to additional columns:\n', \
        crash_data.columns
    print crash_data.describe()
    print '\nFinished Part B.\n'
    return crash_data

# %%
# Declare constants
DATE='Date'
CRASH='Crash'
LINK='Link'
BRIEF='Brief'
PLACE='Place'
CREW='Crew'
PASSENGERS='Passengers'
FATALITIES='Fatalities'
FATALITIESRAW='Fatalities_Raw'
SURVIVORS='Survivors'
REGISTRATION='Registration'
ORIGIN='Origin'
DESTINATION='Destination'
INDEX = 'Index_Copy'

# %%
# QUESTION 1
# Part A.
crashes = make_dataframe()
# Out:
# QUESTION 1: Part A
#  Parsing data into dictionary...
#
# Building dataframe from dictionary...
# Dataframe built:
#  Shape:
#  (1016, 4)
#  Columns: Index([u'Crash', u'Date', u'Link', u'Brief'], dtype='object')
#  Head 10:
#                                        Crash       Date  \
# 0  <__main__.Crash object at 0x7f40eb420810> 1919-08-02
# 1  <__main__.Crash object at 0x7f40eb4206d0> 1922-04-07
# 2  <__main__.Crash object at 0x7f40eb420d50> 1923-05-14
# 3  <__main__.Crash object at 0x7f40eb420d90> 1923-08-27
# 4  <__main__.Crash object at 0x7f40eb420e90> 1924-12-24
# 5  <__main__.Crash object at 0x7f40eb3be6d0> 1926-10-02
# 6  <__main__.Crash object at 0x7f40eb3bed10> 1926-08-18
# 7  <__main__.Crash object at 0x7f40eb3be990> 1927-08-22
# 8  <__main__.Crash object at 0x7f40eb3be350> 1928-07-13
# 9  <__main__.Crash object at 0x7f40eb3be3d0> 1929-06-17
#
#                                                 Link  \
# 0              /wiki/1919_Verona_Caproni_Ca.48_crash
# 1         /wiki/First_mid-air_collision_of_airliners
# 2      /wiki/May_1923_Air_Union_Farman_Goliath_crash
# 3   /wiki/August_1923_Air_Union_Farman_Goliath_crash
# 4  /wiki/1924_Imperial_Airways_de_Havilland_DH.34...
# 5  /wiki/October_1926_Air_Union_Bl%C3%A9riot_155_...
# 6  /wiki/August_1926_Air_Union_Bl%C3%A9riot_155_c...
# 7                 /wiki/1927_KLM_Fokker_F.VIII_crash
# 8   /wiki/1928_Imperial_Airways_Vickers_Vulcan_crash
# 9  /wiki/1929_Imperial_Airways_Handley_Page_W.10_...
#
#                                                Brief
# 0  A Caproni Ca.48 crashes at Verona, Italy, duri...
# 1  e first mid-air collision of airliners, a de H...
# 2  n Air Union Farman F.60 Goliath crashes near M...
# 3  n Air Union Farman F.60 Goliath crashes near E...
# 4  n Imperial Airways de Havilland DH.34 crashes ...
# 5  n Air Union Blriot 155 catches fire in mid-air...
# 6  n Air Union Blriot 155 crashes while attemptin...
# 7  A KLM Fokker F. VIII crashes near Sevenoaks, K...
# 8  n Imperial Airways Vickers Vulcan crashes on a...
# 9  n Imperial Airways Handley Page W.10 ditches i...

# %%
crashes = crashes.sort_values(by=[DATE])
crashes.index = range(0, len(crashes))
crashes.columns
# Out:
# Index([u'Crash', u'Date', u'Link', u'Brief'], dtype='object')

# %%
crashes[INDEX] = crashes.index.tolist()

# %%
crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1016 entries, 0 to 1015
# Data columns (total 5 columns):
# Crash         1016 non-null object
# Date          1016 non-null datetime64[ns]
# Link          1016 non-null object
# Brief         1016 non-null object
# Index_Copy    1016 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 47.6+ KB

# %%
# Part B.
scrape_link(crashes[CRASH], verbose=False)
# Out:
# Part B.
# Scrape data from links and save to Crash object attributes...
#
# ...all data scraped.

# %%
# Copy partial dataframe for safety
crashed = crashes.copy()
crashes = attributes_to_columns(crashes)
# Out:
# Populated attributes to additional columns:
# Index([u'Crash', u'Date', u'Link', u'Brief', u'Index_Copy', u'Survivors',
#        u'Passengers', u'Place', u'Registration', u'Fatalities', u'Destination',
#        u'Raw_Data', u'Origin', u'Crew'],
#       dtype='object')
#         Index_Copy   Survivors  Passengers  Fatalities         Crew
# count  1016.000000  941.000000  995.000000  994.000000  1001.000000
# mean    507.500000   33.726886   73.540704   49.798793     6.956044
# std     293.438239   76.017081   75.581828   57.861206     4.603919
# min       0.000000    0.000000    0.000000    0.000000     1.000000
# 25%     253.750000    0.000000   21.000000   10.000000     4.000000
# 50%     507.500000    1.000000   49.000000   30.500000     6.000000
# 75%     761.250000   24.000000  104.000000   70.000000     8.000000
# max    1015.000000  737.000000  648.000000  583.000000    61.000000
#
# Finished Part B.

# %%
# Copy full dataframe for safety
# crashed = crashes.copy()
# Apply formating fixes to new data
crashes = crashes.fillna(value=np.nan)
crashes[LINK] = crashes.apply(fix_base_link, axis=1)
for COLUMN in ['Destination', 'Origin', 'Registration', 'Brief']:
        crashes[COLUMN] = crashes.apply(lambda row: fix_unicode_lists(row, COLUMN), axis=1)
crashes.head(10)
# Out:
# Taliedo, Milan, Italy
# ['Croydon', 'Le Bourget, Paris']
# _N = 1 (1922-04-07 00:00:00): Destination 2 items: ['Croydon', 'Le Bourget, Paris']
# 	>> Le Bourget, Paris
# Croydon, Surrey, United Kingdom
# Croydon Airport, Surrey, United Kingdom
# Le Bourget, Paris, France
# Croydon Airport, Croydon, United Kingdom
# Croydon Airport, Croydon, United Kingdom
# Waalhaven Airport, Rotterdam
# Croydon Airport, England
# Zurich Airport, Switzerland
# Amsterdam-Schiphol Municipal Airport Netherlands
# Croydon Airport
# nan
# Los Angeles, California
# Croydon Airport
# Oakland, California
# Croydon Airport, United Kingdom
# Croydon, Surrey, United Kingdom
# Berlin Tegel Airport, Germany
# Le Bourget, Paris, France
# Cheyenne, Wyoming
# Croydon Airport, United Kingdom
# Little Rock National Airport, Little Rock, Arkansas
# Los Angeles
# Troms
# Midway Airport, Chicago, Illinois,
# Amsterdam-Schiphol Municipal Airport (AMS/EHAM), Amsterdam, Netherlands
# Los Angeles, California
# Burbank, California
# Sydney Airport, Sydney
# Naval Air Station Lakehurst in Lakehurst Borough, New Jersey, United States
# nan
# Chicago-Midway Airport (MDW/KMDW)
# Auckland, New Zealand
# Winslow, Arizona
# Manila
# Essendon Airport, Melbourne, Victoria
# Southampton
# Seattle-Boeing Field International Airport (BFI/KBFI)
# Bermuda
# Santos Dumont Airport, Rio de Janeiro, Brazil
# Helsinki-Malmi Airport
# Detroit, Michigan
# Ferihegy Airport, Budapest, Hungary
# Brownsville, Texas
# Burbank, California
# nan
# Broome, Western Australia
# ['New York, New York', 'Palm Springs, California']
# _N = 48 (1942-10-23 00:00:00): Destination 2 items: ['New York, New York', 'Palm Springs, California']
# 	>> New York, New York
# San Francisco, California
# Bristol (Whitchurch) Airport, United Kingdom
# Memphis, Tennessee
# Memphis, Tennessee
# Memphis Municipal Airport, Memphis, Tennessee
# Washington D.C.
# nan
# Broken Hill, New South Wales
# nan
# Lakeland, Florida
# California
# Birmingham Municipal Airport, Alabama
# Melbourne
# nan
# Oslo Airport, Gardermoen
# Berlin Tegel Airport, Berlin, Germany
# Amsterdam Schiphol Airport, Netherlands
# Idlewild International Airport
# West Africa
# Salisbury, Rhodesia
# Stockholm Bromma Airport, Sweden
# Aeropuerto de Techo, Bogot
# Cleveland Municipal Airport, Cleveland, Ohio
# Miami International Airport
# Norfolk, Virginia, US
# Istanbul, Turkey
# Los Cerrillos Airport (ULC/SCTI)
# Santiago, Chile
# Oslo
# Chicago Midway Airport
# Juneau, Alaska
# Bombay Santacruz Airport, India
# Bermuda
# New York City, New York
# RAF Gatow
# New York
# Glasgow-Renfrew Airport
# LaGuardia Airport, New York City
# ['RAF Northolt, London, United Kingdom', 'RAF Northolt, London, United Kingdom']
# _N = 86 (1948-07-04 00:00:00): Destination 2 items: ['RAF Northolt, London, United Kingdom', 'RAF Northolt, London, United Kingdom']
# 	>> RAF Northolt, London, United Kingdom
# Hong Kong
# Port-Etienne, French West Africa
# Minneapolis-St. Paul International Airport, Minnesota
# Sydney, New South Wales
# Trondheim-Hommelvika
# New York
# Miami International Airport, Florida
# Kingston, Jamaica
# ['Glasgow-Renfrew Airport, Scotland, United Kingdom', 'RAF Middleton St. George, United Kingdom']
# _N = 95 (1949-02-19 00:00:00): Destination 2 items: ['Glasgow-Renfrew Airport, Scotland, United Kingdom', 'RAF Middleton St. George, United Kingdom']
# 	>> RAF Middleton St. George, United Kingdom
# nan
# Turin, Italy
# Miami, Florida, US
# Carnarvon, Western Australia
# Burbank Airport
# Manchester Airport, England, United Kingdom
# nan
# New York City, United States.
# nan
# nan
# Mexico City Int'l Airport
# Chelyabinsk Airport, Chelyabinsk
# nan
# Llandow aerodrome
# Paris, France
# Paris, France
# Seattle, Washington
# Adelaide Airport
# New York-Idlewild Airport
# Northolt Airport
# London, England
# London
# Paris-Orly Airport
# nan
# New York City
# nan
# Haneda Army Air Base, Tokyo, Japan
# San Francisco
# John Paul II International Airport KrakwBalice
# Tampa International Airport, Florida
# Tehran Airport, Iran
# Buffalo, New York
# Newark, New Jersey
# Miami, Florida
# Paris-Le Bourget Airport (LBG/LFPB), Paris
# New York City-Idlewild International Airport, United States
# Idlewild Airport, New York
# ['Dallas Love Field', 'Dallas Love Field']
# _N = 132 (1952-06-28 00:00:00): Destination 2 items: ['Dallas Love Field', 'Dallas Love Field']
# 	>> Dallas Love Field
# Goiania-Santa Genoveva Airport, Brazil
# Jos Mart International Airport, Cuba
# Nutts Corner, Belfast, Northern Ireland
# Jamaica
# Oakland, California, US
# Tehran-Mehrabad Airport (THR/OIII)
# Nice Airport, France
# Chicago Midway Airport, Illinois
# nan
# London Heathrow Airport, London, England
# London
# Johannesburg Jan Smuts
# Hong Kong
# New York City
# Prestwick Airport
# ['Cleveland-Hopkins International Airport', 'Lexington, Kentucky']
# _N = 148 (1955-01-12 00:00:00): Destination 2 items: ['Cleveland-Hopkins International Airport', 'Lexington, Kentucky']
# 	>> Cleveland-Hopkins International Airport
# Santa Fe Municipal Airport, NM (SAF/KSAF)
# Sydney, Australia
# LaGuardia Airport, New York City, New York, United States
# Kemayoran Airport, Jakarta, Indonesia
# Lod Airport
# nan
# Seattle-Tacoma International Airport, Seattle, Washington
# London Stansted Airport, United Kingdom
# Newark International Airport, NJ (EWR/KEWR)
# New York, New York
# Caracas-Simn Bolvar International Airport (CCS/SVMI)
# Tripoli International Airport (Idris Airport), Libya
# ['Chicago Midway Airport', 'Kansas City Downtown Airport']
# _N = 161 (1956-06-30 00:00:00): Destination 2 items: ['Chicago Midway Airport', 'Kansas City Downtown Airport']
# 	>> Kansas City Downtown Airport
# nan
# nan
# Oslo Airport, Fornebu
# Caracas Airport (CCS/SVMI)
# nan
# nan
# Manchester Airport, England
# RAF Castel Benito / RAF Idris, Libya
# Manila International Airport (MNL/RPLL)
# Toronto Pearson International Airport, Toronto, Ontario
# nan
# nan
# Manchester Airport, England
# Manchester Airport
# Freeland-Tri City Airport
# ['New York City', 'Nellis Air Force Base']
# _N = 177 (1958-04-21 00:00:00): Destination 2 items: ['New York City', 'Nellis Air Force Base']
# 	>> Nellis Air Force Base
# New Delhi
# Benina International Airport, Libya
# New York City
# Nantucket Memorial Airport
# Tel Aviv
# Naples Airport, Italy
# Barajas Airport, Madrid
# Hurn Airfield (Now Bournemouth International)
# Tri-Cities Regional Airport, Bristol, Tennessee, United States
# Rio de Janeiro-Galeo International Airport, Brazil
# nan
# London Heathrow Airport, United Kingdom (diverted to London Gatwick Airport due to fog at Heathrow)
# Woomera Airfield, Australia
# nan
# Paris-Orly Airport (ORY) (ORY/LFPO), France
# London-Gatwick Airport, United Kingdom
# Abidjan, Ivory Coast
# LaGuardia Airport, New York City
# Charlottesville-Albemarle Airport
# nan
# Kabul International Airport, Afghanistan
# Miami, Florida
# nan
# Cairo, Egypt
# El Dorado International Airport
# ['Galeo Air Force Base', 'Rio de Janeiro-Santos Dumont Airport']
# _N = 203 (1960-02-25 00:00:00): Destination 2 items: ['Galeo Air Force Base', 'Rio de Janeiro-Santos Dumont Airport']
# 	>> Rio de Janeiro-Santos Dumont Airport
# Miami International Airport, Miami, Florida
# Mackay Airport
# Mackay, Queensland
# Aba Segud Airport
# Sheremetyevo International Airport, Moscow
# nan
# nan
# ['Idlewild Airport (IDL/KIDL) (now John F. Kennedy International Airport), NY', 'LaGuardia Airport (LGA/KLGA), New York']
# _N = 210 (1960-12-16 00:00:00): Destination 2 items: ['Idlewild Airport (IDL/KIDL) (now John F. Kennedy International Airport), NY', 'LaGuardia Airport (LGA/KLGA), New York']
# Santiago, Chile
# Frankfurt Airport
# nan
# Mnchen-Riem Airport (MUC/EDDM)
# Eppley Airfield
# Rawalpindi International Airport
# ['Duluth, Minnesota, U.S.', "O'Hare International Airport, Chicago, Illinois, U.S."]
# _N = 401 (1972-12-20 00:00:00): Destination 2 items: ['Duluth, Minnesota, U.S.', "O'Hare International Airport, Chicago, Illinois, U.S."]
# 	>> O'Hare International Airport, Chicago, Illinois, U.S.
# Oslo Airport, Fornebu
# Miami International Airport
# Ikeja Int'l Airport, Lagos (now Murtala Muhammad Int'l Airport)
# Nicosia International Airport
# Cairo International Airport
# Sheremetyevo International Airport, Moscow, Soviet Union
# Basle-Mulhouse Airport
# Palam International Airport, New Delhi, India
# Lic. Gustavo Daz Ordaz International Airport
# Orly Airport
# San Francisco International Airport, California, United States
# Tokyo International Airport, Tokyo, Japan
# St. Louis International Airport, St. Louis, Missouri, United States
# Logan International Airport, Boston, Massachusetts
# Alvedro Airport, A Corua, Spain
# nan
# nan
# Omsk Tsentralny Airport, Soviet Union
# Domodedovo Airport, Moscow, Russia
# San Francisco International Airport
# nan
# Istanbul Yeilky Airport (IST/LTBA), Turkey
# Los Angeles International Airport
# London Heathrow Airport
# London, United Kingdom
# ['Munich Airport, Germany', 'Ringway Airport, Manchester, Greater Manchester']
# _N = 426 (1974-04-18 00:00:00): Destination 2 items: ['Munich Airport, Germany', 'Ringway Airport, Manchester, Greater Manchester']
# 	>> Munich Airport, Germany
# Sydney (Kingsford-Smith) Airport
# John F. Kennedy International Airport
# nan
# Saigon-Tan Son Nhat Int'l Airport
# Saigon, South Vietnam
# Jan Smuts Int'l Airport
# Johannesburg, South Africa
# Dulles International
# diverted from National Airport
# Jeddah International Airport, Jeddah, Saudi Arabia
# Simn Bolvar International Airport, Venezuela
# Los Angeles Airport
# Istanbul Yeilky Airport, Turkey
# Casper/Natrona County International Airport, Wyoming, United States
# nan
# Inezgane Airport, Agadir
# Tehran International Airport, Iran
# Gambell Airport Gambell, Alaska, United States
# Leipzig/Halle Airport
# Sultan Mahmud Badaruddin II Airport, Palembang
# Beirut International Airport
# Prague Ruzyn Airport
# Abu Dhabi International Airport
# Brest Airport (BQT/UMBB)
# Harry S. Truman Airport, Saint Thomas, U.S. Virgin Islands
# Sheremetyevo International Airport, Moscow, Russia
# nan
# nan
# Cuenca, Ecuador
# ["Yeilky Int'l Airport\nIstanbul, Turkey", 'Cologne Bonn Airport\nCologne, West Germany']
# _N = 453 (1976-09-10 00:00:00): Destination 2 items: ["Yeilky Int'l Airport\nIstanbul, Turkey", 'Cologne Bonn Airport\nCologne, West Germany']
# 	>> Cologne Bonn Airport
# Cologne, West Germany
# Antalya Airport,
# Turkey
# nan
# Madras Airport
# Kozani National Airport, Kozani, Greece
# Don Mueang International Airport, Thailand
# Stockholm Bromma Airport
# ['Gran Canaria Airport\nCanary Islands, Spain', 'Gran Canaria Airport\nCanary Islands, Spain']
# Husein Sastranegara International Airport, Bandung , Indonesia
# Nha Trang Airport (NHA/VVNT)
# Guilin Liangjiang International Airport
# Faro Airport
# Tripoli International Airport
# Paris-Charles de Gaulle Airport, France
# ['Mashhad International Airport', 'Mehrabad International Airport']
# _N = 674 (1993-02-08 00:00:00): Destination 2 items: ['Mashhad International Airport', 'Mehrabad International Airport']
# 	>> Mashhad International Airport
# Addis Ababa, Ethiopia
# Zurich-Kloten Airport
# Los Angeles International Airport, Los Angeles, California, United States
# New Chitose Airport
# nan
# nan
# Beijing Capital International Airport
# Mokpo Airport (MPK)
# nan
# ['Sukhumi-Babusheri Airport', 'Sukhumi-Babusheri Airport']
# _N = 684 (1993-09-21 00:00:00): Destination 2 items: ['Sukhumi-Babusheri Airport', 'Sukhumi-Babusheri Airport']
# 	>> Sukhumi-Babusheri Airport
# ['Sukhumi-Babusheri Airport', 'Sukhumi-Babusheri Airport']
# _N = 685 (1993-09-22 00:00:00): Destination 2 items: ['Sukhumi-Babusheri Airport', 'Sukhumi-Babusheri Airport']
# 	>> Sukhumi-Babusheri Airport
# nan
# Namsos Airport, Hknesra
# Kai Tak Airport, Hong Kong
# nan
# Skopje Airport
# Chisholm-Hibbing Airport
# Domodedovo International Airport, Moscow
# Kai Tak Airport, Hong Kong
# Cardiff International Airport, Cardiff, United Kingdom
# San Jose International Airport
# San Jose, California
# Nagoya Airport
# Guangzhou Baiyun International Airport (former) (CAN/ZGGG), China
# Charlotte/Douglas Int'l Airport
# Tocumen International Airport
# Panama City, Panama
# Casablanca-Mohamed V Airport (CMN/GMMN)
# West Palm Beach Int'l Airport
# Mehrabad Airport, Iran
# Chicago O'Hare International Airport
# nan
# Narita International Airport
# nan
# Paris-Orly Airport
# Van Ferit Melen Airport, Van, Turkey
# Rafael Nez International Airport, Cartagena, Colombia
# Brae Alpha oil rig, Brae oilfield, North Sea
# Brussel-Zaventem Airport
# Palmerston North International Airport
# El Salvador International Airport, San Salvador, El Salvador
# Gulfport-Biloxi International Airport
# Tawau Airport, Malaysia
# nan
# Lagos Airport (LOS)
# Douala International Airport, Douala, Cameroon
# Baku-Bina International Airport (BAK/UBBB), Baku
# nan
# Timioara International Airport
# unknown (northern Angola)
# Alfonso Bonilla Aragn Int'l Airport
# Kahemba Airport
# Frankfurt Airport
# Frankfurt, Germany
# Crnl. FAP C. C. Santa Rosa Int'l Airport
# Tacna, Peru
# William B. Hartsfield Atlanta Int'l Airport, Atlanta, Georgia
# Richmond International Airport
# Soekarno Hatta Int'l Airport, Jakarta, Indonesia
# Hartsfield-Jackson Atlanta International Airport
# Leonardo da Vinci Int'l Airport
# Rome
# Malta International Airport, Malta
# Svalbard Airport, Longyear, Longyearbyen, Norway
# Comodoro Arturo Merino Bentez International Airport
# Santiago, Chile
# nan
# Lagos Airport
# ['Dhahran International Airport\nDhahran, Saudi Arabia', "Indira Gandhi Int'l Airport"]
# _N = 737 (1996-11-12 00:00:00): Destination 2 items: ['Dhahran International Airport\nDhahran, Saudi Arabia', "Indira Gandhi Int'l Airport"]
# 	>> Barcelona Int'l Airport
# Barcelona, Spain
# Maya-Maya Airport, Brazzaville, CAR
# Fuhlsbttel Airport, Hamburg, Germany
# Rio Branco International Airport, Rio Branco, Brazil
# New Tokyo International Airport
# (Narita, Chiba)
# Luxembourg Findel Airport
# Laoag International Airport
# Greenville-Spartanburg Int'l Airport
# Diyarbakr Airport, Turkey
# Chachapoyas Airport
# Noumrat  Moufdi Zakaria Airport, Ghardaia
# Zaragoza Airport, Zaragoza, Spain
# nan
# Khartoum International Airport
# Bahrain International Airport
# Memphis International Airport, Memphis, Tennessee
# Dubai International Airport, Dubai, United Arab Emirates
# Charles de Gaulle Airport
# Paris, France
# Sharjah International Airport, Sharjah, United Arab Emirates
# nan
# Cincinnati/Northern Kentucky International Airport
# ['Volgograd International Airport, Volgograd', 'Adler-Sochi International Airport, Sochi']
# _N = 827 (2004-08-24 00:00:00): Destination 2 items: ['Volgograd International Airport, Volgograd', 'Adler-Sochi International Airport, Sochi']
# 	>> Adler-Sochi International Airport, Sochi
# ['Volgograd International Airport, Volgograd', 'Adler-Sochi International Airport, Sochi']
# _N = 828 (2004-08-24 00:00:00): Destination 2 items: ['Volgograd International Airport, Volgograd', 'Adler-Sochi International Airport, Sochi']
# 	>> Volgograd International Airport, Volgograd
# Zaragoza Airport,
# Spain
# Kirksville Regional Airport
# Shanghai Hongqiao International Airport, Shanghai, China
# Juanda International Airport
# Surabaya, Indonesia
# Kabul International Airport
# London Heathrow, UK
# Jean Lesage Airport, Quebec, Quebec, Canada
# Varandey Airport, Nenetskiy Avtonomnyy Okrug, Russia
# ['Shannon Airport\nShannon, Ireland', "Philadelphia Int'l Airport\nPhiladelphia, Pennsylvania"]
# _N = 837 (2005-06-09 00:00:00): Destination 2 items: ['Shannon Airport\nShannon, Ireland', "Philadelphia Int'l Airport\nPhiladelphia, Pennsylvania"]
# 	>> Philadelphia Int'l Airport
# Philadelphia, Pennsylvania
# Bata Airport
# Toronto Pearson International Airport
# Mississauga, Ontario, Canada
# Djerba-Zarzis Airport, Tunisia
# nan
# Prague Ruzyn Int'l Airport, Prague, Czech Republic
# Martinique Aim Csaire Int'l Airport
# Crnl. FAP F. S. Vignetta Int'l Airport
# Iquitos, Peru
# Ngurah Rai International Airport
# Denpasar, Indonesia
# Matari Airport, Isiro, Democratic Republic of the Congo
# Kinshasa, Democratic Republic of the Congo
# John F. Kennedy Int'l Airport, New York City
# Nnamdi Azikiwe International Airport, Abuja
# McCarran International Airport
# Las Vegas, Nevada
# Port Harcourt International Airport, Port Harcourt, Nigeria
# Bimini, Bahamas
# Aktau Airport, Kazakhstan
# Adler Airport, Sochi
# Irkutsk International Airport
# Allama Iqbal International Airport, Lahore
# Frankfurt Airport
# Pulkovo Airport, Saint Petersburg, Russia
# Hartsfield-Jackson Atlanta International Airport
# Mashhad International Airport, Mashhad
# ["Galeo Int'l Airport\nRio de Janeiro, Brazil", 'Eduardo Gomes International Airport']
# _N = 95 (1949-02-19 00:00:00): Origin 2 items: ['Northolt Airport, England, United Kingdom', 'RAF Middleton St. George, United Kingdom']
# 	>> RAF Middleton St. George, United Kingdom
# nan
# Lisbon, Portugal
# San Juan, Puerto Rico, US
# Perth, Western Australia
# Albuquerque Municipal Airport
# Nutts Cormer Airport, Belfast, Northern Ireland, United Kingdom
# nan
# Paris-Orly Airport, France.
# nan
# nan
# LaGuardia Airport, New York City
# Vnukovo Airport, Moscow, USSR
# nan
# Dublin Airport
# Saigon, Vietnam
# Saigon, Vietnam
# LaGuardia Airport
# New York City, New York
# Perth Airport
# Bombay International Airport, India
# Paris Le Bourget Airport
# Paris, France
# Bombay
# Roma-Ciampino Airport
# nan
# Johannesburg, Union of South Africa
# nan
# Vancouver International Airport, British Columbia, Canada
# Boston
# Lublinek Airport
# Newark Airport, New Jersey
# Baghdad Airport, Iraq
# Miami, Florida
# Buffalo, New York
# Newark Airport, New Jersey
# Tunis-El Aouina Airport (TUN/DTTA), Tunisia
# San Juan-Isla Grande Airport, Puerto Rico
# Buenos Aires, Argentina
# ['San Francisco International Airport', 'Denton, Texas']
# _N = 132 (1952-06-28 00:00:00): Origin 2 items: ['San Francisco International Airport', 'Denton, Texas']
# 	>> San Francisco International Airport
# Rio Verde Airport, Brazil
# Kindley Air Force Base now L.F. Wade International Airport, Bermuda
# RAF Northolt, England , United Kingdom
# Stansted Airport, United Kingdom
# Guam, US Territory
# Paris-Orly Airport (ORY/LFPO)
# Orly Airport, Paris, France
# Boston Airport
# nan
# Kallang Airport, Singapore
# Sydney
# London Heathrow Airport
# Bangkok
# Amsterdam
# London Heathrow Airport
# ['Boone County Airport', 'Battle Creek']
# _N = 148 (1955-01-12 00:00:00): Origin 2 items: ['Boone County Airport', 'Battle Creek']
# 	>> Boone County Airport
# Albuquerque International Airport, NM (ABQ/KABQ)
# Seattle-Tacoma, Washington
# Long Island MacArthur Airport, Ronkonkoma, Islip, New York, United States
# Santa Cruz Airport, Bombay, India
# London Heathrow Airport
# nan
# LaGuardia Airport, New York, New York
# RAF Luqa, Malta
# Pittsburgh International Airport, PA (PIT/KPIT)
# Seattle-Tacoma International Airport
# New York-Idlewild International Airport (IDL/KIDL)
# Kano Airport, Nigeria
# ["Los Angeles Int'l Airport", "Los Angeles Int'l Airport"]
# _N = 161 (1956-06-30 00:00:00): Origin 2 items: ["Los Angeles Int'l Airport", "Los Angeles Int'l Airport"]
# 	>> Los Angeles Int'l Airport
# nan
# nan
# Trondheim Airport, Vrnes
# New York-Idlewild International Airport (IDL/KIDL)
# nan
# nan
# Schiphol International Airport, Amsterdam, Netherlands
# Blackbushe Airport
# Biak-Mokmer Airport (BIK/WABB)
# London Heathrow International Airport, London
# nan
# nan
# Belgrade Airport, Yugoslavia
# Ronaldsway Airport
# Flint-Bishop Airport
# ['Los Angeles, California', 'Nellis Air Force Base, Nevada']
# _N = 177 (1958-04-21 00:00:00): Origin 2 items: ['Los Angeles, California', 'Nellis Air Force Base, Nevada']
# 	>> Nellis Air Force Base, Nevada
#  Caribbean Airlines Flight 523, a Boeing 737, overruns the runway on landing at Cheddi Jagan International Airport, Georgetown, Guyana, and breaks in two; seven are injured but all 163 passengers and crew survive.
# e 2011 Avis Amur Antonov An-12 crash, an Antonov An-12, en route from Magadan Airport to Keperveyem Airport, crashes at Omsukchan, Russia, due to an engine fire, killing all 11 on board.
#  First Air Flight 6560, a Boeing 737, crashes while on approach to Resolute Bay Airport, Nunavut, Canada, killing 12 of 15 on board.
#  Aerocon Flight 238, a Fairchild Metroliner III, crashes near Trinidad, Bolivia, killing 8 of 9 people on board.
#  Yak-Service Flight 9634, a Yakovlev Yak-42, crashes just after takeoff from Tunoshna Airport, Yaroslavl, Russia, due to pilot error, killing 44 of the 45 people on board. Many were players and staff of the Lokomotiv Yaroslavl ice hockey team of the KHL, as the flight was destined for Minsk, Belarus for a league game.
#  Buddha Air Flight 103, a Beechcraft 1900D, crashes in dense fog while attempting to land at Kathmandu Tribhuwan International Airport, killing all 16 passengers and 3 crew members.
#  Airlines PNG Flight 1600, a de Havilland Canada DHC-8, crashes near the mouth of the Gogol River, Papua New Guinea, killing 28 of 32 on board.
#  Iran Air Flight 742, a Boeing 727, en route from Moscow, Russia, to Tehran, Iran, lands without nose gear at Mehrabad International Airport; all 94 passengers and 14 crew members survive without injuries.
#  LOT Polish Airlines Flight 16, a Boeing 767, performs a belly landing at Warsaw Chopin Airport after its landing gear failed to deploy; all 220 passengers and 11 crew members survive without injuries.
#  UTair Flight 120, an ATR-72, crashes shortly after takeoff from Roshchino International Airport, Tyumen, Russia, killing 31 of the 43 passengers and crew on board.
#  Bhoja Air Flight 213, a Boeing 737, crashes near Chaklala airbase, Rawalpindi, Pakistan, in bad weather, killing all 127 people on board.
# e Mount Salak Sukhoi Superjet 100 crash, a Sukhoi Superjet 100 crashes into Mount Salak, Indonesia, on an exhibition flight, killing all 45 passengers and crew on board.
# e Agni Air Flight CHT, a Dornier Do 228 crashes near Jomsom Airport, Nepal, during a go-around; of the 21 on board, 6 survive.
#  Allied Air Flight 111, a Boeing 727, overruns the runway on landing at Kotoka International Airport, Accra, Ghana, and crashes through a fence; the aircraft then hits a bus on a nearby road; all 4 crew survive but 12 are killed on the ground.
#  Dana Air Flight 992, a McDonnell Douglas MD-83 carrying 147 passengers and 6 crew members crashes in a suburb of Lagos, Nigeria, on approach to Murtala Muhammed International Airport, killing all on board and 10 more people on the ground.
# k Tianjin Airlines Flight 7554, an Embraer E-190, 10 minutes after takeoff; passengers and crew are able to restrain the hijackers until the aircraft makes an emergency landing; of the 101 on board, 2 hijackers die and 11 passengers and crew are injured; this is China's first serious hijacking attempt since 1990.
#  Petropavlovsk-Kamchatsky Air Flight 251, an Antonov An-28, crashes in Kamchatka Peninsula, Russia, killing 10 of the 14 passengers and crew on board.
#  Sita Air Flight 601, a Dornier Do 228, crashes on the bank of the Manohara River, Kathmandu, Nepal, after a bird strike, killing all 19 on board.
#  FlyMontserrat Flight 107, a Britten-Norman Islander, crashes after takeoff from V.C. Bird International Airport, Antigua and Barbuda; of the 4 on board, only 1 survives.
# - Daallo Airlines Flight 159, an Airbus A321, suffers an explosion shortly after taking off from Mogadishu's International Airport. Three people are injured and one, the suspected suicide bomber, is killed after falling from the aircraft.
# - Tara Air Flight 193, a Viking Air-built DHC-6 Twin Otter, flies into a storm and crashes into a mountain side at Dana, Myagdi district, Nepal killing all 23 on board.
#                                        Crash       Date  \
# 0  <__main__.Crash object at 0x7f40eb420810> 1919-08-02
# 1  <__main__.Crash object at 0x7f40eb4206d0> 1922-04-07
# 2  <__main__.Crash object at 0x7f40eb420d50> 1923-05-14
# 3  <__main__.Crash object at 0x7f40eb420d90> 1923-08-27
# 4  <__main__.Crash object at 0x7f40eb420e90> 1924-12-24
# 5  <__main__.Crash object at 0x7f40eb3bed10> 1926-08-18
# 6  <__main__.Crash object at 0x7f40eb3be6d0> 1926-10-02
# 7  <__main__.Crash object at 0x7f40eb3be990> 1927-08-22
# 8  <__main__.Crash object at 0x7f40eb3be350> 1928-07-13
# 9  <__main__.Crash object at 0x7f40eb3be3d0> 1929-06-17
#
#                                                 Link  \
# 0  https://en.wikipedia.org/wiki/1919_Verona_Capr...
# 1  https://en.wikipedia.org/wiki/First_mid-air_co...
# 2  https://en.wikipedia.org/wiki/May_1923_Air_Uni...
# 3  https://en.wikipedia.org/wiki/August_1923_Air_...
# 4  https://en.wikipedia.org/wiki/1924_Imperial_Ai...
# 5  https://en.wikipedia.org/wiki/August_1926_Air_...
# 6  https://en.wikipedia.org/wiki/October_1926_Air...
# 7  https://en.wikipedia.org/wiki/1927_KLM_Fokker_...
# 8  https://en.wikipedia.org/wiki/1928_Imperial_Ai...
# 9  https://en.wikipedia.org/wiki/1929_Imperial_Ai...
#
#                                                Brief  Index_Copy  Survivors  \
# 0  A Caproni Ca.48 crashes at Verona, Italy, duri...           0          0
# 1  e first mid-air collision of airliners, a de H...           1          0
# 2  n Air Union Farman F.60 Goliath crashes near M...           2          0
# 3  n Air Union Farman F.60 Goliath crashes near E...           3         12
# 4  n Imperial Airways de Havilland DH.34 crashes ...           4          0
# 5  n Air Union Blriot 155 crashes while attemptin...           5         12
# 6  n Air Union Blriot 155 catches fire in mid-air...           6          0
# 7  A KLM Fokker F. VIII crashes near Sevenoaks, K...           7         10
# 8  n Imperial Airways Vickers Vulcan crashes on a...           8          2
# 9  n Imperial Airways Handley Page W.10 ditches i...           9          6
#
#    Passengers                                     Place Registration  \
# 0          12                             Verona, Italy      Caproni
# 1           3  Thieuloy-Saint-Antoine, Picardie, France       G-EAWO
# 2           4                   Monsures, Somme, France       F-AEBY
# 3          11        East Malling, Kent, United Kingdom       F-AECB
# 4           7            Purley, Surrey, United Kingdom       G-EBBX
# 5          13      College Farm, Hurst, Aldington, Kent       F-AIEB
# 6           5                               Leigh, Kent       F-AICQ
# 7           9                          Underriver, Kent       H-NADU
# 8           5                       near Purley, Surrey       G-EBLB
# 9          11            English Channel, off Dungeness       G-EBMT
#
#    Fatalities                               Destination  \
# 0          14                     Taliedo, Milan, Italy
# 1           7                         Le Bourget, Paris
# 2           6           Croydon, Surrey, United Kingdom
# 3           1   Croydon Airport, Surrey, United Kingdom
# 4           8                 Le Bourget, Paris, France
# 5           3  Croydon Airport, Croydon, United Kingdom
# 6           7  Croydon Airport, Croydon, United Kingdom
# 7           1              Waalhaven Airport, Rotterdam
# 8           4                  Croydon Airport, England
# 9           7               Zurich Airport, Switzerland
#
#                                             Raw_Data  \
# 0  [[Site, Verona, Italy], [Passengers, 12], [Cre...
# 1  [[Site, Thieuloy-Saint-Antoine, Picardie, Fran...
# 2  [[Site, Monsures, Somme, France], [Passengers,...
# 3  [[Site, East Malling, Kent, United Kingdom], [...
# 4  [[Site, Purley, Surrey, United Kingdom], [Pass...
# 5  [[Site, College Farm, Hurst, Aldington, Kent],...
# 6  [[Site, Leigh, Kent], [Passengers, 5], [Crew, ...
# 7  [[Site, Underriver, Kent], [Passengers, 9], [C...
# 8  [[Site, near Purley, Surrey], [Passengers, 5],...
# 9  [[Site, English Channel, off Dungeness], [Pass...
#
#                               Origin  Crew
# 0                      Venice, Italy     2
# 1                            Croydon     4
# 2          Le Bourget, Paris, France     2
# 3  Le Bourget Airport, Paris, France     2
# 4    Croydon, Surrey, United Kingdom     1
# 5  Le Bourget Airport, Paris, France     2
# 6  Le Bourget Airport, Paris, France     2
# 7                    Croydon Airport     2
# 8           Croydon Airport, England     1
# 9    Croydon Airport, United Kingdom     2

# %%
# Part C.
# Which were the top 5 most deadly aviation incidents?
# Report the number of fatalities and the flight origin for each.
# Copy full dataframe for safety
crashed = crashes.copy()
crashed[INDEX] = crashed.index.tolist()
crashes = crashes.sort_values(by=[FATALITIES], ascending=False)
crashes.index = range(0, len(crashes))
crashes[INDEX] = crashes.index.tolist()
print '\nPart C. Sort By Most Fatalities:\n', \
    crashes[[FATALITIES,ORIGIN, DATE]][:5]
print '\nFLIGHT ORIGIN WITH THE MOST FATALITIES:\n', crashes[ORIGIN][0], '({})'.format(crashes[FATALITIES][0]), \
      'REGISTERED AS:',crashes[REGISTRATION][0], '\n\nSUMMARY:\n'
for i in range(len(crashes[[FATALITIES,ORIGIN, DATE]][:5])):
    print '\n{}.'.format(i + 1), crashes[DATE][i], \
            '\nDeparted from', crashes[ORIGIN][i], \
            'towards', crashes[DESTINATION][i], \
            '\nCrash occured in', crashes[PLACE][i], \
            '\nDescribed as:\n\t', crashes[BRIEF][i]
# Out:
# Part C. Sort By Most Fatalities:
#    Fatalities                                             Origin       Date
# 0         583  Los Angeles Int'l Airport\nLos Angeles, United... 1977-03-27
# 1         349                             Shymkent Int'l Airport 1996-11-12
# 2         346            Yesilky Int'l Airport\nIstanbul, Turkey 1974-03-03
# 3         329  Toronto (as Flight 181) Montral-Mirabel Int'l ... 1985-06-23
# 4         301      Quaid-e-Azam Int'l Airport\nKarachi, Pakistan 1980-08-19
#
# FLIGHT ORIGIN WITH THE MOST FATALITIES:
# Los Angeles Int'l Airport
# Los Angeles, United States (583.0) REGISTERED AS: N736PA
#
# SUMMARY:
#
#
# 1. 1977-03-27 00:00:00
# Departed from Los Angeles Int'l Airport
# Los Angeles, United States towards Gran Canaria Airport
# Canary Islands, Spain
# Crash occured in Los Rodeos Airport
# Described as:
# 	e Tenerife airport disaster, KLM Flight 4805 and Pan Am Flight 1736, both Boeing 747s, collide on the runway at Los Rodeos Airport; 583 of 644 people on board both aircraft are killed in the worst accident in the history of commercial aviation.
#
# 2. 1996-11-12 00:00:00
# Departed from Shymkent Int'l Airport towards Indira Gandhi Int'l Airport
# Crash occured in Charkhi Dadri, Haryana, India
# Described as:
# 	 Charkhi Dadri mid-air collision: Saudi Arabian Airlines Flight 763, a Boeing 747, collides in mid-air with Air Kazakhstan Flight 1907, an Ilyushin Il-76, near Charkhi Dadri, India. All 312 on board the Boeing 747 and all 37 on board the Ilyushin Il-76 are killed. It is the deadliest mid-air collision in aviation history.
#
# 3. 1974-03-03 00:00:00
# Departed from Yesilky Int'l Airport
# Istanbul, Turkey towards London Heathrow Airport
# London, United Kingdom
# Crash occured in Ermenonville Forest
# Described as:
# 	 Turkish Airlines Flight 981, a McDonnell Douglas DC-10, crashes in the Ermenonville forest near Senlis, France, after the rear underfloor cargo door opens in mid-flight; all 346 on board die.
#
# 4. 1985-06-23 00:00:00
# Departed from Toronto (as Flight 181) Montral-Mirabel Int'l Airport
# Montreal, Canada towards Indira Gandhi Int'l Airport
# New Delhi, India
# Crash occured in Atlantic Ocean, southwest of Ireland
# Described as:
# 	 Air India Flight 182, a Boeing 747 en route from MontralMirabel International Airport to London Heathrow Airport, is destroyed over the Atlantic Ocean near Ireland by a bomb planted by Sikh extremists, killing all 329 people on board.
#
# 5. 1980-08-19 00:00:00
# Departed from Quaid-e-Azam Int'l Airport
# Karachi, Pakistan towards Jeddah International Airport
# Jeddah, Saudi Arabia
# Crash occured in Riyadh, Saudi Arabia
# Described as:
# 	 Saudia Flight 163, a Lockheed L-1011 Tristar, lands at King Khalid International Airport in Riyadh, Saudi Arabia, when a fire breaks out on board; the evacuation of the plane is delayed and all 301 on board die.

# %%
# Part D
# Which flight origin has the highest number of aviation
# incidents in the last 25 years?
today = dt.date.today()
yearsago25 = dt.date(today.year - 25, today.month, 28)
last_25years = crashes[crashes[DATE] >= yearsago25]
by_origin = last_25years.groupby([ORIGIN]).size().sort_values(ascending=False)
print '\nPart D. Total Incidents By Origin:\n', by_origin[:5]
print '\nFLIGHT ORIGIN WITH THE MOST INCIDENTS:\n', by_origin[:1], '\n\nINCLUDES:\n'
deadliest_origin = crashes[crashes[ORIGIN]=='Ninoy Aquino International Airport'][INDEX]
deadliest_origin = deadliest_origin.tolist()
deadliest_origin
print len(deadliest_origin), 'incidents:'
for i in range(len(deadliest_origin)):
    print '\n{}.'.format(i + 1), crashes[DATE][deadliest_origin[i]], \
            '\nDeparted from', crashes[ORIGIN][deadliest_origin[i]], \
            'towards', crashes[DESTINATION][deadliest_origin[i]], \
            '\nCrash occured in', crashes[PLACE][deadliest_origin[i]], \
            '\nDescribed as:\n\t', crashes[BRIEF][deadliest_origin[i]]
# Out:
# Part D. Total Incidents By Origin:
# Origin
# Domodedovo International Airport, Moscow        3
# Ninoy Aquino International Airport              3
# Murtala Mohammed Airport, Lagos                 2
# Amsterdam Airport Schiphol                      2
# Jos Mart International Airport, Havana, Cuba    2
# dtype: int64
#
# FLIGHT ORIGIN WITH THE MOST INCIDENTS:
# Origin
# Domodedovo International Airport, Moscow    3
# dtype: int64
#
# INCLUDES:
#
# 3 incidents:
#
# 1. 2002-11-11 00:00:00
# Departed from Ninoy Aquino International Airport towards Laoag International Airport
# Crash occured in Manila Bay, Philippines
# Described as:
# 	 Laoag International Airlines Flight 585, a Fokker F-27 Friendship, crashes into Manila Bay shortly after takeoff from Ninoy Aquino International Airport; of the 34 people on board, 19 are killed.
#
# 2. 1999-12-07 00:00:00
# Departed from Ninoy Aquino International Airport towards Cauayan Airport
# Crash occured in Between Kasibu, Nueva Vizcaya and Cabarroguis, Quirino, Philippines
# Described as:
# 	 Asian Spirit Flight 100, a Let L-410 Turbolet, crashes into a mountain while on approach to Cauayan Airport, killing all 15 passengers and crew on board.
#
# 3. 1998-03-22 00:00:00
# Departed from Ninoy Aquino International Airport towards Bacolod City Domestic Airport
# Crash occured in Bacolod City Domestic Airport
# Described as:
# 	 Philippine Airlines Flight 137, an Airbus A320, overshoots the end of the runway while landing at Bacolod City in the Philippines, plowing through several houses. None of the passengers was harmed, but three people on the ground are killed and several more injured.

# %%
# Part E.
# Save this Dataframe as JSON and commit to your repo,
# along with the notebook / python code used to do this assignment.
# myjson = crashed_fix.to_json('crash_json', orient='index') DOESNT WORK.
    # In [185]: myjson = crashed_fix.to_json('crash_json', orient='index')
    # Segmentation fault
    # studentuser@data-science-rocks:~/ppha_30530/pa4$
myjson = crashes.to_json('crash_json') # Friday submission

# %%
# Sanity checks
crashes[[DATE, LINK, PLACE, ORIGIN, DESTINATION, BRIEF]][crashes[DATE] == dt.date(2001, 9, 11)]
# Out:
#           Date                                               Link  \
# 173 2001-09-11  https://en.wikipedia.org/wiki/American_Airline...
# 266 2001-09-11  https://en.wikipedia.org/wiki/United_Airlines_...
# 269 2001-09-11  https://en.wikipedia.org/wiki/American_Airline...
# 398 2001-09-11  https://en.wikipedia.org/wiki/United_Airlines_...
#
#                                                  Place  \
# 173  North Tower of the World Trade Center, Manhatt...
# 266  South Tower of the World Trade Center, Manhatt...
# 269  West wall of Pentagon, Arlington County, Virgi...
# 398  Field near the Diamond T. Mine, a coal strip m...
#
#                                                 Origin  \
# 173                        Logan International Airport
# 266                                Logan Int'l Airport
# 269            Washington Dulles International Airport
# 398  Newark Int'l Airport (now Newark Liberty Int'l...
#
#                            Destination  \
# 173  Los Angeles International Airport
# 266          Los Angeles Int'l Airport
# 269  Los Angeles International Airport
# 398        San Francisco Int'l Airport
#
#                                                  Brief
# 173  , a Boeing 767-200ER with 92 people on board, ...
# 266                                                  .
# 269  , a Boeing 757-200 with 64 people on board, is...
# 398  , a Boeing 757-200 with 44 people on board, is...
